# %%
## imports
import pandas as pd
import numpy as np
import re
import requests
import yaml


## repeated printouts
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# # 1. Example 1: no credentials; no wrapper
#
# Site: National Assessment of Education Progress (NAEP)
#
# Documentation: https://www.nationsreportcard.gov/api_documentation.aspx
#
# Base link: https://www.nationsreportcard.gov/DataService/GetAdhocData.aspx

# %% [markdown]
# ## 1.1 Query to pull some data

# %%
## using their example query of 2011 writing scores separated by gender
## based on here - https://stackoverflow.com/questions/40836749/pythonic-way-of-writing-a-single-line-long-string
## using the ( ) syntax to formulate a long
## string without linebreaks added
example_naep_query = (
'https://www.nationsreportcard.gov/'
'Dataservice/GetAdhocData.aspx?'
'type=data&subject=writing&grade=8&'
'subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2011')


example_naep_query
# Out:
# 'https://www.nationsreportcard.gov/Dataservice/GetAdhocData.aspx?type=data&subject=writing&grade=8&subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2011'

# %%
## use requests to call the api
naep_resp = requests.get(example_naep_query)
naep_resp
print(type(naep_resp))

## get the json contents of the response 
## here, we're assuming valid response
naep_resp_j = naep_resp.json()
naep_resp_j

## with result, turn it into a dataframe
naep_resp_d = pd.DataFrame(naep_resp_j['result'])
naep_resp_d
# Out:
# <Response [200]>
# <class 'requests.models.Response'>
# {'status': 200,
#  'result': [{'year': 2011,
#    'sample': 'R3',
#    'yearSampleLabel': '2011',
#    'Cohort': 2,
#    'CohortLabel': 'Grade 8',
#    'stattype': 'MN:MN',
#    'subject': 'WRI',
#    'grade': 8,
#    'scale': 'WRIRP',
#    'jurisdiction': 'NP',
#    'jurisLabel': 'National public',
#    'variable': 'GENDER',
#    'variableLabel': 'Gender',
#    'varValue': '1',
#    'varValueLabel': 'Male',
#    'value': 139.099504632971,
#    'isStatDisplayable': 1,
#    'errorFlag': 0},
#   {'year': 2011,
#    'sample': 'R3',
#    'yearSampleLabel': '2011',
#    'Cohort': 2,
#    'CohortLabel': 'Grade 8',
#    'stattype': 'MN:MN',
#    'subject': 'WRI',
#    'grade': 8,
#    'scale': 'WRIRP',
#    'jurisdiction': 'NP',
#    'jurisLabel': 'National public',
#    'variable': 'GENDER',
#    'variableLabel': 'Gender',
#    'varValue': '2',
#    'varValueLabel': 'Female',
#    'value': 158.567104984955,
#    'isStatDisplayable': 1,
#    'errorFlag': 0}]}
#    year sample yearSampleLabel  Cohort CohortLabel stattype subject  grade  \
# 0  2011     R3            2011       2     Grade 8    MN:MN     WRI      8
# 1  2011     R3            2011       2     Grade 8    MN:MN     WRI      8
#
#    scale jurisdiction       jurisLabel variable variableLabel varValue  \
# 0  WRIRP           NP  National public   GENDER        Gender        1
# 1  WRIRP           NP  National public   GENDER        Gender        2
#
#   varValueLabel       value  isStatDisplayable  errorFlag
# 0          Male  139.099505                  1          0
# 1        Female  158.567105                  1          0

# %% [markdown]
# ## 1.2 What happens if there's an error in our query?

# %%
## here's a query that from the documentation we know
## won't work since i modified year to 2025 which doesnt
## exist in the data
wrong_naep_query = (
'https://www.nationsreportcard.gov/'
'Dataservice/GetAdhocData.aspx?'
'type=data&subject=writing&grade=8&'
'subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2025')

wrong_naep_query
# Out:
# 'https://www.nationsreportcard.gov/Dataservice/GetAdhocData.aspx?type=data&subject=writing&grade=8&subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2025'

# %%
## use requests to call the api
naep_wrong_resp = requests.get(wrong_naep_query)
naep_wrong_resp
# Out:
# <Response [200]>

# %%
## in the case of this particular api,
## the call returns some response but
## when we try to extract the json containing
## status or results, we get in an error
#naep_wrong_resp.json() # uncomment to see error

# %%
naep_wrong_resp.text
# Out:
# '{"status":400,"result": "System.Exception: The query \'SELECT DISTINCT Framework FROM Cycles WHERE Subject=\'WRI\' AND Cohort=2 AND CONVERT(VARCHAR(10),Year)+Sample IN (\'2025R3\')\' did not return exactly 1 framework. Make sure you can trend the years defined for the given subject and cohort.\r\n   at NRCDataService3.GetAdhocData.GetFramework(NDEContext& ndeContext, String subjectCode, List`1 yearSamples, String cohort) in C:\\projects\\ndecore2015\\NRCDataService2\\GetAdhocData.aspx.cs:line 2380\r\n   at NRCDataService3.GetAdhocData.PopulateBaseOrchestratorRequest() in C:\\projects\\ndecore2015\\NRCDataService2\\GetAdhocData.aspx.cs:line 2010\r\n   at NRCDataService3.GetAdhocData.ConstructRequest_Datapoint() in C:\\projects\\ndecore2015\\NRCDataService2\\GetAdhocData.aspx.cs:line 651\r\n   at NRCDataService3.GetAdhocData.Page_Load(Object sender, EventArgs e) in C:\\projects\\ndecore2015\\NRCDataService2\\GetAdhocData.aspx.cs:line 191"}'

# %% [markdown]
# ### 1.2.2 More all-purpose way of allowing remainder of calls to run: try, except

# %%
## putting it in a try; except as general error catching
try:
    results = naep_wrong_resp.json()['result']
except Exception as e:
    print('Failed to get result from API due to error:')
    print(e) # or just: pass
# Out:
# Failed to get result from API due to error:
# Invalid control character at: line 1 column 289 (char 288)

# %% [markdown]
# ### 1.2.3 Can usually also find more targeted way but that varies more across APIs

# %%
## if we wanted do more specific error catching,
## see that the status == 400 actually appears here
## so could write if else along those lines
naep_wrong_resp.text
naep_resp.text

if "System.Exception" in naep_wrong_resp.text:
    print("NAEP results not found")
# Out:
# '{"status":400,"result": "System.Exception: The query \'SELECT DISTINCT Framework FROM Cycles WHERE Subject=\'WRI\' AND Cohort=2 AND CONVERT(VARCHAR(10),Year)+Sample IN (\'2025R3\')\' did not return exactly 1 framework. Make sure you can trend the years defined for the given subject and cohort.\r\n   at NRCDataService3.GetAdhocData.GetFramework(NDEContext& ndeContext, String subjectCode, List`1 yearSamples, String cohort) in C:\\projects\\ndecore2015\\NRCDataService2\\GetAdhocData.aspx.cs:line 2380\r\n   at NRCDataService3.GetAdhocData.PopulateBaseOrchestratorRequest() in C:\\projects\\ndecore2015\\NRCDataService2\\GetAdhocData.aspx.cs:line 2010\r\n   at NRCDataService3.GetAdhocData.ConstructRequest_Datapoint() in C:\\projects\\ndecore2015\\NRCDataService2\\GetAdhocData.aspx.cs:line 651\r\n   at NRCDataService3.GetAdhocData.Page_Load(Object sender, EventArgs e) in C:\\projects\\ndecore2015\\NRCDataService2\\GetAdhocData.aspx.cs:line 191"}'
# '{"status":200,"result": [{"year":2011,"sample":"R3","yearSampleLabel":"2011","Cohort":2,"CohortLabel":"Grade 8","stattype":"MN:MN","subject":"WRI","grade":8,"scale":"WRIRP","jurisdiction":"NP","jurisLabel":"National public","variable":"GENDER","variableLabel":"Gender","varValue":"1","varValueLabel":"Male","value":139.099504632971,"isStatDisplayable":1,"errorFlag":0},{"year":2011,"sample":"R3","yearSampleLabel":"2011","Cohort":2,"CohortLabel":"Grade 8","stattype":"MN:MN","subject":"WRI","grade":8,"scale":"WRIRP","jurisdiction":"NP","jurisLabel":"National public","variable":"GENDER","variableLabel":"Gender","varValue":"2","varValueLabel":"Female","value":158.567104984955,"isStatDisplayable":1,"errorFlag":0}]}'
# NAEP results not found

# %% [markdown]
# ## Activity 1: writing a function to make multiple, sequential calls
#
# - Say we want to pull the data for grades 4, 8, and 12
# - How can we write a function that iterates over a list of those grades and pulls the data for each grade?
#
# **Note**: an ideal function would have arguments for each parameter in the API like subject, subscale, etc. Here we can leave those other parts constant

# %%
example_naep_query = (
'https://www.nationsreportcard.gov/'
'Dataservice/GetAdhocData.aspx?'
'type=data&subject=writing&grade=8&'
'subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2011')

# %%
def naep_api_calls(grades: list,
                   baseurl = 'https://www.nationsreportcard.gov/Dataservice/GetAdhocData.aspx?',
                   query_part1 = 'type=data&subject=writing',
                   query_part3 = '&subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2011'):
                       
    '''This function calls the NAEP API to get data on writing scores for the grade requested in 2011.
    
    Parameters:
        baseurl (str): default URL for NAEP or similar API
        query_part1 (str): first batch of arguments
        grades (list of int): what grades to get data on
        query_part3 (str): third batch of arguments
    Returns:
        DataFrame with the results'''
    
    dflist = []
    
    for grade in grades:
        naep_query = baseurl + query_part1  + query_part3 + ('&grade=' + str(grade))
        naep_resp = requests.get(naep_query)
        
        #if "System.Exception" in naep_resp.text:
        #    print(f"NAEP results not found for grade {str(grade)}, please try with grade in range of 1-12")
        #else:
        try:
            naep_resp_df = pd.DataFrame(naep_resp.json()['result'])
            dflist.append(naep_resp_df)
        except Exception as e:
            print("Failed to get result from API for grade {} due to error:".format(str(grade)))
            print(e)
        
    combined_result_df = pd.concat(dflist)
    
    return(combined_result_df)


naep_api_calls(grades = [4,8,12])
# Out:
# Failed to get result from API for grade 4 due to error:
# Invalid control character at: line 1 column 289 (char 288)
#    year sample yearSampleLabel  Cohort CohortLabel stattype subject  grade  \
# 0  2011     R3            2011       2     Grade 8    MN:MN     WRI      8
# 1  2011     R3            2011       2     Grade 8    MN:MN     WRI      8
# 0  2011     R3            2011       3    Grade 12    MN:MN     WRI     12
# 1  2011     R3            2011       3    Grade 12    MN:MN     WRI     12
#
#    scale jurisdiction       jurisLabel variable variableLabel varValue  \
# 0  WRIRP           NP  National public   GENDER        Gender        1
# 1  WRIRP           NP  National public   GENDER        Gender        2
# 0  WRIRP           NP  National public   GENDER        Gender        1
# 1  WRIRP           NP  National public   GENDER        Gender        2
#
#   varValueLabel       value  isStatDisplayable  errorFlag
# 0          Male  139.099505                  1          0
# 1        Female  158.567105                  1          0
# 0          Male  141.256978                  1          0
# 1        Female  155.385917                  1          0

# %% [markdown]
# # 2. Example 2: needs credentials; no wrapper

# %%
# Format example

# %%
API_KEY = "Your Key"

# %%
## use documentation to define what to search
## doc: https://www.yelp.com/developers/documentation/v3/business_search
## write the query 
base_url = "https://api.yelp.com/v3/businesses/search?"
my_name = "restaurants"
my_location = "Hanover,NH,03755"
yelp_genquery = ('{base_url}'
                'term={name}'
                '&location={loc}').format(base_url = base_url,
                name = my_name,
                loc = my_location)

## use requests to call the API; here, we're
## passing it our credentials (structure varies
## by API and telling it to only return 10 results
## (max is 50 at once)
header = {'Authorization': f"Bearer {API_KEY}"}
yelp_genresp = requests.get(yelp_genquery, headers = header)
yelp_genresp

## then, look at structure of response
yelp_genjson = yelp_genresp.json()
# Out:
# <Response [200]>

# %%
yelp_genjson["businesses"]
# Out:
# [{'id': 'XVGEEIH5rVB2QzW-qywcJw',
#   'alias': 'base-camp-cafe-hanover',
#   'name': 'Base Camp Cafe',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/p8_YiEQI7p_JF82eaWa9Xg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/base-camp-cafe-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'review_count': 247,
#   'categories': [{'alias': 'himalayan', 'title': 'Himalayan/Nepalese'}],
#   'rating': 4.4,
#   'coordinates': {'latitude': 43.700626, 'longitude': -72.2887803},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '3 Lebanon St',
#    'address2': 'Ste 13',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['3 Lebanon St', 'Ste 13', 'Hanover, NH 03755']},
#   'phone': '+16036432007',
#   'display_phone': '(603) 643-2007',
#   'distance': 196.1397581876442},
#  {'id': '5WW4g_LRwau29KyjZGLyAA',
#   'alias': 'sawtooth-kitchen-hanover',
#   'name': 'Sawtooth Kitchen',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/61MNG4d1fmE2TW1Ie_b01w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sawtooth-kitchen-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'review_count': 25,
#   'categories': [{'alias': 'chickenshop', 'title': 'Chicken Shop'}],
#   'rating': 4.1,
#   'coordinates': {'latitude': 43.70158, 'longitude': -72.289641},
#   'transactions': [],
#   'location': {'address1': '33 S Main St',
#    'address2': '',
#    'address3': None,
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['33 S Main St', 'Hanover, NH 03755']},
#   'phone': '+16036435134',
#   'display_phone': '(603) 643-5134',
#   'distance': 242.6075518026577},
#  {'id': 'KA8yhrd-ClVYMyOefXdVYg',
#   'alias': 'lous-restaurant-and-bakery-hanover',
#   'name': "Lou's Restaurant & Bakery",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/VAx8H9Xy_Dc_mAY-nuNt9A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lous-restaurant-and-bakery-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'review_count': 383,
#   'categories': [{'alias': 'tradamerican', 'title': 'American'},
#    {'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'donuts', 'title': 'Donuts'}],
#   'rating': 4.2,
#   'coordinates': {'latitude': 43.70143, 'longitude': -72.289001},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '30 S Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['30 S Main St', 'Hanover, NH 03755']},
#   'phone': '+16036433321',
#   'display_phone': '(603) 643-3321',
#   'distance': 244.00605927937792},
#  {'id': 'jAFLKiVXq9z_h4ZPy0nLMA',
#   'alias': 'the-works-café-hanover',
#   'name': 'The Works Café',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/olpsy-B-taHe8lT6YYDViQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-works-caf%C3%A9-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'review_count': 11,
#   'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 43.701789, 'longitude': -72.289672},
#   'transactions': [],
#   'location': {'address1': '25 S Main St',
#    'address2': '',
#    'address3': None,
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['25 S Main St', 'Hanover, NH 03755']},
#   'phone': '+16032772082',
#   'display_phone': '(603) 277-2082',
#   'distance': 293.8675321816416},
#  {'id': '8ybF6YyRldtZmU9jil4xlg',
#   'alias': 'mollys-restaurant-and-bar-hanover',
#   'name': "Molly's Restaurant & Bar",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TJLrrA6z-SnPgZfrs2GQNQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mollys-restaurant-and-bar-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'review_count': 508,
#   'categories': [{'alias': 'tradamerican', 'title': 'American'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.9,
#   'coordinates': {'latitude': 43.701144, 'longitude': -72.2894249},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '43 South Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['43 South Main St', 'Hanover, NH 03755']},
#   'phone': '+16036432570',
#   'display_phone': '(603) 643-2570',
#   'distance': 250.8301601841674},
#  {'id': '34j_2nRCVQBTKafJvncZlg',
#   'alias': 'pine-restaurant-hanover-2',
#   'name': 'PINE Restaurant',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/c2SgURpO89OGUXP3r_sM8w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pine-restaurant-hanover-2?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'review_count': 226,
#   'categories': [{'alias': 'newamerican', 'title': 'New American'}],
#   'rating': 3.6,
#   'coordinates': {'latitude': 43.7024572, 'longitude': -72.2875656},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '2 E Wheelock St',
#    'address2': None,
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['2 E Wheelock St', 'Hanover, NH 03755']},
#   'phone': '+16036468000',
#   'display_phone': '(603) 646-8000',
#   'distance': 256.00429144986015},
#  {'id': 'vMyN7JL5cJExJORgIobbQg',
#   'alias': 'tuk-tuk-thai-cuisine-hanover',
#   'name': 'Tuk Tuk Thai Cuisine',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/--bUG38dWvNQ0V3f6e9iEQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tuk-tuk-thai-cuisine-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'review_count': 308,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.3,
#   'coordinates': {'latitude': 43.70202, 'longitude': -72.28953},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '5 S Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['5 S Main St', 'Hanover, NH 03755']},
#   'phone': '+16032779192',
#   'display_phone': '(603) 277-9192',
#   'distance': 309.8168422593178},
#  {'id': 'eba9e8OxN7pAhxoDT-J0ww',
#   'alias': 'the-nest-kitchen-hanover',
#   'name': 'The Nest Kitchen',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3Ume3C8ImR817N_OL9QgcA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-nest-kitchen-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'review_count': 21,
#   'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#   'rating': 3.9,
#   'coordinates': {'latitude': 43.70059612109659,
#    'longitude': -72.28988918523648},
#   'transactions': [],
#   'location': {'address1': '57 S Main St',
#    'address2': None,
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['57 S Main St', 'Hanover, NH 03755']},
#   'phone': '+16032772916',
#   'display_phone': '(603) 277-2916',
#   'distance': 285.28661217098033},
#  {'id': 'neBEWvgHNhsXIBImCYx_6A',
#   'alias': 'murphy-s-on-the-green-hanover',
#   'name': 'Murphy’s on the Green',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/76DCQrgDN8Nqe3QKDA-opw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/murphy-s-on-the-green-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'review_count': 175,
#   'categories': [{'alias': 'newamerican', 'title': 'New American'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'pubs', 'title': 'Pubs'}],
#   'rating': 3.7,
#   'coordinates': {'latitude': 43.702, 'longitude': -72.2894949},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '11 S Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['11 S Main St', 'Hanover, NH 03755']},
#   'phone': '+16036434075',
#   'display_phone': '(603) 643-4075',
#   'distance': 295.20752311926014},
#  {'id': 'qxm3VNmD0O2zw8m9U8SxZg',
#   'alias': 'duende-hanover-2',
#   'name': 'Duende',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rf_h2DP7M3BtubbWHprQDg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/duende-hanover-2?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'review_count': 11,
#   'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#    {'alias': 'bakeries', 'title': 'Bakeries'}],
#   'rating': 3.8,
#   'coordinates': {'latitude': 43.70074272457673,
#    'longitude': -72.2876837477088},
#   'transactions': [],
#   'location': {'address1': '15 Lebanon St',
#    'address2': '',
#    'address3': None,
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['15 Lebanon St', 'Hanover, NH 03755']},
#   'phone': '+16033064826',
#   'display_phone': '(603) 306-4826',
#   'distance': 107.38886229011861},
#  {'id': 'wyV_NfYn4ZOfp_sHMDPcAw',
#   'alias': 'bistro-at-six-hanover',
#   'name': 'Bistro at Six',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/i4jvssUsxa79VYVLOD3TmQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bistro-at-six-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'review_count': 3,
#   'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'tradamerican', 'title': 'American'}],
#   'rating': 3.7,
#   'coordinates': {'latitude': 43.7001146, 'longitude': -72.2877078},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '6 E South St',
#    'address2': None,
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['6 E South St', 'Hanover, NH 03755']},
#   'phone': '+16036430600',
#   'display_phone': '(603) 643-0600',
#   'distance': 198.65178837196856},
#  {'id': 'Tg8O0iPqeD_IjFGwTLqacw',
#   'alias': 'han-fusion-hanover',
#   'name': 'Han Fusion',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CvUlbJi7Hb03cQCJErPf-A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/han-fusion-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'review_count': 54,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.2,
#   'coordinates': {'latitude': 43.700641, 'longitude': -72.2887803},
#   'transactions': ['delivery'],
#   'location': {'address1': '3 Lebanon St',
#    'address2': 'Ste 15',
#    'address3': None,
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['3 Lebanon St', 'Ste 15', 'Hanover, NH 03755']},
#   'phone': '+16036438888',
#   'display_phone': '(603) 643-8888',
#   'distance': 196.01251786876801},
#  {'id': 'uZ6rg3gYgoWqFB5tOB49VQ',
#   'alias': 'tacos-y-tequila-hanover',
#   'name': 'Tacos Y Tequila',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2tr2DorwXG0scfVi79Rz-A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tacos-y-tequila-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'review_count': 30,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#   'rating': 3.2,
#   'coordinates': {'latitude': 43.70063761388881, 'longitude': -72.2887803},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '3 Lebanon St',
#    'address2': '',
#    'address3': None,
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['3 Lebanon St', 'Hanover, NH 03755']},
#   'phone': '+16036963155',
#   'display_phone': '(603) 696-3155',
#   'distance': 196.04000826741668},
#  {'id': '1yTM59uje_iMMdwKXI7-sA',
#   'alias': 'umplebys-bakery-and-cafe-hanover',
#   'name': "Umpleby's Bakery & Cafe",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jlAlp5GmOrf1YvueIm6HeQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/umplebys-bakery-and-cafe-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'review_count': 79,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'customcakes', 'title': 'Custom Cakes'}],
#   'rating': 3.1,
#   'coordinates': {'latitude': 43.69993, 'longitude': -72.288839},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '3 South St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['3 South St', 'Hanover, NH 03755']},
#   'phone': '+16036433030',
#   'display_phone': '(603) 643-3030',
#   'distance': 220.8437964167156},
#  {'id': 'GXX6xbCK1EBH9X6zJf3wVA',
#   'alias': 'sushiya-hanover-2',
#   'name': 'Sushiya',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/h9lEGQGmH4Rk8ZQu3Z9zDg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sushiya-hanover-2?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'review_count': 96,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 43.699737, 'longitude': -72.289326},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '72 S Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['72 S Main St', 'Hanover, NH 03755']},
#   'phone': '+16036434000',
#   'display_phone': '(603) 643-4000',
#   'distance': 265.40959563254313},
#  {'id': 'Ecdu5qYM09F647Uoez99vg',
#   'alias': 'ramuntos-brick-and-brew-pizzeria-hanover',
#   'name': "Ramunto's Brick & Brew Pizzeria",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bPy9NZGEsPsmi8dtCzI77w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ramuntos-brick-and-brew-pizzeria-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'review_count': 137,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.6,
#   'coordinates': {'latitude': 43.6998454, 'longitude': -72.2877323},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '9 E South St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['9 E South St', 'Hanover, NH 03755']},
#   'phone': '+16036439500',
#   'display_phone': '(603) 643-9500',
#   'distance': 163.8825828645752},
#  {'id': 'EAE-lFuMDeDIIlDtVba79w',
#   'alias': 'dunks-hanover',
#   'name': 'Dunks',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RYe7AKZFGba46UQ3sisQog/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dunks-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'review_count': 8,
#   'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#    {'alias': 'newamerican', 'title': 'New American'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 43.70072, 'longitude': -72.28945},
#   'transactions': [],
#   'location': {'address1': '7 Lebanon St',
#    'address2': '',
#    'address3': None,
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['7 Lebanon St', 'Hanover, NH 03755']},
#   'phone': '+16032779102',
#   'display_phone': '(603) 277-9102',
#   'distance': 169.82167790259317},
#  {'id': 'YJ3XYASE8ML-Tb18Q7Qfyg',
#   'alias': 'boloco-hanover-6',
#   'name': 'Boloco',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Jf7PzeOU8j955uazxuIJwg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/boloco-hanover-6?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'review_count': 126,
#   'categories': [{'alias': 'newamerican', 'title': 'New American'}],
#   'rating': 3.6,
#   'coordinates': {'latitude': 43.7013062264829,
#    'longitude': -72.2895859997003},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '35 S Main St',
#    'address2': '',
#    'address3': 'Dartmouth College',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['35 S Main St',
#     'Dartmouth College',
#     'Hanover, NH 03755']},
#   'phone': '+16036430202',
#   'display_phone': '(603) 643-0202',
#   'distance': 267.06370075516855},
#  {'id': 'VmMQltoybbk2XFQlWXktLw',
#   'alias': 'jewel-of-india-hanover',
#   'name': 'Jewel of India',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xhyLnDNqDa2-J9EooMhyuw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jewel-of-india-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'review_count': 158,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#   'rating': 3.2,
#   'coordinates': {'latitude': 43.700907, 'longitude': -72.286006},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '11 Lebanon St',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['11 Lebanon St', 'Hanover, NH 03755']},
#   'phone': '+16036432217',
#   'display_phone': '(603) 643-2217',
#   'distance': 31.564101493166955},
#  {'id': '5vKVnel7PsD9Mv_Ki1tkUQ',
#   'alias': 'samosa-man-hanover',
#   'name': 'Samosa Man',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/samosa-man-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'review_count': 5,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 43.70047, 'longitude': -72.28914},
#   'transactions': [],
#   'location': {'address1': '50 S Main St',
#    'address2': 'Unit 14',
#    'address3': None,
#    'city': 'Hanover',
#    'zip_code': '03755',
#    'country': 'US',
#    'state': 'NH',
#    'display_address': ['50 S Main St', 'Unit 14', 'Hanover, NH 03755']},
#   'phone': '+18022337783',
#   'display_phone': '(802) 233-7783',
#   'distance': 231.123140472225}]

# %%
## example business
yelp_genjson['businesses'][0]

## more automatic way of summarizing but things end up in lists
## within columns for things like categories
yelp_gendf = pd.DataFrame(yelp_genjson['businesses'])
yelp_gendf.head()
# Out:
# {'id': 'XVGEEIH5rVB2QzW-qywcJw',
#  'alias': 'base-camp-cafe-hanover',
#  'name': 'Base Camp Cafe',
#  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/p8_YiEQI7p_JF82eaWa9Xg/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/base-camp-cafe-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#  'review_count': 238,
#  'categories': [{'alias': 'himalayan', 'title': 'Himalayan/Nepalese'}],
#  'rating': 4.5,
#  'coordinates': {'latitude': 43.700626, 'longitude': -72.2887803},
#  'transactions': ['delivery'],
#  'price': '$$',
#  'location': {'address1': '3 Lebanon St',
#   'address2': 'Ste 13',
#   'address3': '',
#   'city': 'Hanover',
#   'zip_code': '03755',
#   'country': 'US',
#   'state': 'NH',
#   'display_address': ['3 Lebanon St', 'Ste 13', 'Hanover, NH 03755']},
#  'phone': '+16036432007',
#  'display_phone': '(603) 643-2007',
#  'distance': 196.1397581876442}
#                        id                               alias  \
# 0  XVGEEIH5rVB2QzW-qywcJw              base-camp-cafe-hanover
# 1  8ybF6YyRldtZmU9jil4xlg   mollys-restaurant-and-bar-hanover
# 2  5WW4g_LRwau29KyjZGLyAA            sawtooth-kitchen-hanover
# 3  neBEWvgHNhsXIBImCYx_6A       murphy-s-on-the-green-hanover
# 4  KA8yhrd-ClVYMyOefXdVYg  lous-restaurant-and-bakery-hanover
#
#                         name  \
# 0             Base Camp Cafe
# 1   Molly's Restaurant & Bar
# 2           Sawtooth Kitchen
# 3      Murphy’s on the Green
# 4  Lou's Restaurant & Bakery
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/p8_YiE...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/TJLrrA...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/61MNG4...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/76DCQr...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/VAx8H9...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/base-camp-cafe-hanove...           238
# 1  https://www.yelp.com/biz/mollys-restaurant-and...           500
# 2  https://www.yelp.com/biz/sawtooth-kitchen-hano...            19
# 3  https://www.yelp.com/biz/murphy-s-on-the-green...           173
# 4  https://www.yelp.com/biz/lous-restaurant-and-b...           374
#
#                                           categories  rating  \
# 0  [{'alias': 'himalayan', 'title': 'Himalayan/Ne...     4.5
# 1  [{'alias': 'tradamerican', 'title': 'American ...     4.0
# 2  [{'alias': 'chickenshop', 'title': 'Chicken Sh...     4.0
# 3  [{'alias': 'newamerican', 'title': 'American (...     4.0
# 4  [{'alias': 'tradamerican', 'title': 'American ...     4.0
#
#                                          coordinates transactions price  \
# 0  {'latitude': 43.700626, 'longitude': -72.2887803}   [delivery]    $$
# 1  {'latitude': 43.701144, 'longitude': -72.2894249}   [delivery]    $$
# 2    {'latitude': 43.70158, 'longitude': -72.289641}           []   NaN
# 3     {'latitude': 43.702, 'longitude': -72.2894949}   [delivery]    $$
# 4    {'latitude': 43.70143, 'longitude': -72.289001}   [delivery]    $$
#
#                                             location         phone  \
# 0  {'address1': '3 Lebanon St', 'address2': 'Ste ...  +16036432007
# 1  {'address1': '43 South Main St', 'address2': '...  +16036432570
# 2  {'address1': '33 S Main St', 'address2': '', '...  +16036435134
# 3  {'address1': '11 S Main St', 'address2': '', '...  +16036434075
# 4  {'address1': '30 S Main St', 'address2': '', '...  +16036433321
#
#     display_phone    distance
# 0  (603) 643-2007  196.139758
# 1  (603) 643-2570  250.830160
# 2  (603) 643-5134  242.607552
# 3  (603) 643-4075  295.207523
# 4  (603) 643-3321  244.006059

# %%
## more data-specific way of summarizing
## we're doing a simple approach and just retaining
## cols that have a simple str structure
## if doing for real, would want to extract things
def clean_yelp_json(one_biz):

    ## restrict to str cols
    d_str = {key:value for key, value in one_biz.items()
             if type(value) == str}
    
    df_str = pd.DataFrame(d_str, index = [d_str['id']])
    return(df_str)

yelp_stronly = [clean_yelp_json(one_b) for one_b in yelp_genjson['businesses']]
yelp_stronly_df = pd.concat(yelp_stronly)

yelp_stronly_df.head(7)
# Out:
#                                             id  \
# XVGEEIH5rVB2QzW-qywcJw  XVGEEIH5rVB2QzW-qywcJw
# 8ybF6YyRldtZmU9jil4xlg  8ybF6YyRldtZmU9jil4xlg
# 5WW4g_LRwau29KyjZGLyAA  5WW4g_LRwau29KyjZGLyAA
# neBEWvgHNhsXIBImCYx_6A  neBEWvgHNhsXIBImCYx_6A
# KA8yhrd-ClVYMyOefXdVYg  KA8yhrd-ClVYMyOefXdVYg
# 34j_2nRCVQBTKafJvncZlg  34j_2nRCVQBTKafJvncZlg
# vMyN7JL5cJExJORgIobbQg  vMyN7JL5cJExJORgIobbQg
#
#                                                      alias  \
# XVGEEIH5rVB2QzW-qywcJw              base-camp-cafe-hanover
# 8ybF6YyRldtZmU9jil4xlg   mollys-restaurant-and-bar-hanover
# 5WW4g_LRwau29KyjZGLyAA            sawtooth-kitchen-hanover
# neBEWvgHNhsXIBImCYx_6A       murphy-s-on-the-green-hanover
# KA8yhrd-ClVYMyOefXdVYg  lous-restaurant-and-bakery-hanover
# 34j_2nRCVQBTKafJvncZlg           pine-restaurant-hanover-2
# vMyN7JL5cJExJORgIobbQg        tuk-tuk-thai-cuisine-hanover
#
#                                              name  \
# XVGEEIH5rVB2QzW-qywcJw             Base Camp Cafe
# 8ybF6YyRldtZmU9jil4xlg   Molly's Restaurant & Bar
# 5WW4g_LRwau29KyjZGLyAA           Sawtooth Kitchen
# neBEWvgHNhsXIBImCYx_6A      Murphy’s on the Green
# KA8yhrd-ClVYMyOefXdVYg  Lou's Restaurant & Bakery
# 34j_2nRCVQBTKafJvncZlg            PINE Restaurant
# vMyN7JL5cJExJORgIobbQg       Tuk Tuk Thai Cuisine
#
#                                                                 image_url  \
# XVGEEIH5rVB2QzW-qywcJw  https://s3-media1.fl.yelpcdn.com/bphoto/p8_YiE...
# 8ybF6YyRldtZmU9jil4xlg  https://s3-media4.fl.yelpcdn.com/bphoto/TJLrrA...
# 5WW4g_LRwau29KyjZGLyAA  https://s3-media3.fl.yelpcdn.com/bphoto/61MNG4...
# neBEWvgHNhsXIBImCYx_6A  https://s3-media2.fl.yelpcdn.com/bphoto/76DCQr...
# KA8yhrd-ClVYMyOefXdVYg  https://s3-media3.fl.yelpcdn.com/bphoto/VAx8H9...
# 34j_2nRCVQBTKafJvncZlg  https://s3-media2.fl.yelpcdn.com/bphoto/rD7w_r...
# vMyN7JL5cJExJORgIobbQg  https://s3-media4.fl.yelpcdn.com/bphoto/--bUG3...
#
#                                                                       url  \
# XVGEEIH5rVB2QzW-qywcJw  https://www.yelp.com/biz/base-camp-cafe-hanove...
# 8ybF6YyRldtZmU9jil4xlg  https://www.yelp.com/biz/mollys-restaurant-and...
# 5WW4g_LRwau29KyjZGLyAA  https://www.yelp.com/biz/sawtooth-kitchen-hano...
# neBEWvgHNhsXIBImCYx_6A  https://www.yelp.com/biz/murphy-s-on-the-green...
# KA8yhrd-ClVYMyOefXdVYg  https://www.yelp.com/biz/lous-restaurant-and-b...
# 34j_2nRCVQBTKafJvncZlg  https://www.yelp.com/biz/pine-restaurant-hanov...
# vMyN7JL5cJExJORgIobbQg  https://www.yelp.com/biz/tuk-tuk-thai-cuisine-...
#
#                        price         phone   display_phone
# XVGEEIH5rVB2QzW-qywcJw    $$  +16036432007  (603) 643-2007
# 8ybF6YyRldtZmU9jil4xlg    $$  +16036432570  (603) 643-2570
# 5WW4g_LRwau29KyjZGLyAA   NaN  +16036435134  (603) 643-5134
# neBEWvgHNhsXIBImCYx_6A    $$  +16036434075  (603) 643-4075
# KA8yhrd-ClVYMyOefXdVYg    $$  +16036433321  (603) 643-3321
# 34j_2nRCVQBTKafJvncZlg   $$$  +16036468000  (603) 646-8000
# vMyN7JL5cJExJORgIobbQg    $$  +16032779192  (603) 277-9192

# %% [markdown]
# # Activity 2: pull restaurants in a different location
#
# - Try running a business search query for your hometown or another place by constructing a query similar to `yelp_genquery` but changing the location parameter
# - Other endpoints require feeding what's called the business' fusion id into the API. Take an id from `yelp_stronly.id` and use the documentation here to pull the reviews for that business: https://www.yelp.com/developers/documentation/v3/business_reviews
# - **Challenge**: generalize the previous step by writing a function that (1) takes a list of business ids as an input, (2) calls the reviews API for each id, (3) returns the results, and (4) rowbinds all results, i.e. turns them into a single, usable DataFrame

# %%
# change location
base_url = "https://api.yelp.com/v3/businesses/search?"
my_name = "restaurants"
# my_location_marlow = "Marlow,NH,03456"
my_location_tpe = "Taipei,Taiwan,03456"
yelp_genquery_tpe = ('{base_url}'
                'term={name}'
                '&location={loc}').format(base_url = base_url,
                name = my_name,
                loc = my_location_marlow)

## use requests to call the API
header = {'Authorization': f"Bearer {API_KEY}"}
yelp_genresp_ = requests.get(yelp_genquery_tpe, headers = header)
yelp_genresp_tpe

## then, look at structure of response
yelp_genjson_marlow = yelp_genresp_marlow.json()

## turn JSON into usable data (DF)
yelp_gendf_marlow = pd.DataFrame(yelp_genjson_marlow['businesses'])
#list(yelp_gendf_marlow) # list columns
yelp_gendf_marlow['location1'] = yelp_gendf_marlow.location.apply(lambda loclist: loclist['address1'])
yelp_gendf_marlow[['alias', 'name', 'url', 'review_count', 'rating', 'location1', 'price']]

# Optional: Restrict to cols that are just strings
#yelp_stronly_marlow = [clean_yelp_json(one_b) for one_b in yelp_genjson_marlow['businesses']]
#yelp_stronly_marlow_df = pd.concat(yelp_stronly_marlow)

#yelp_stronly_marlow_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 13
#       6 yelp_genquery_marlow = ('{base_url}'
#       7                 'term={name}'
#       8                 '&location={loc}').format(base_url = base_url,
#       9                 name = my_name,
#      10                 loc = my_location_marlow)
#      12 ## use requests to call the API
# ---> 13 header = {'Authorization': f"Bearer {API_KEY}"}
#      14 yelp_genresp_ = requests.get(yelp_genquery_marlow, headers = header)
#      15 yelp_genresp_marlow
#
# NameError: name 'API_KEY' is not defined

# %%
# change location
base_url = "https://api.yelp.com/v3/businesses/search?"
my_name = "restaurants"
my_location_marlow = "Marlow,NH,03456"
yelp_genquery_marlow = ('{base_url}'
                'term={name}'
                '&location={loc}').format(base_url = base_url,
                name = my_name,
                loc = my_location_marlow)

## use requests to call the API
header = {'Authorization': f"Bearer {API_KEY}"}
yelp_genresp_marlow = requests.get(yelp_genquery_marlow, headers = header)
yelp_genresp_marlow

## then, look at structure of response
yelp_genjson_marlow = yelp_genresp_marlow.json()

## turn JSON into usable data (DF)
yelp_gendf_marlow = pd.DataFrame(yelp_genjson_marlow['businesses'])
#list(yelp_gendf_marlow) # list columns
yelp_gendf_marlow['location1'] = yelp_gendf_marlow.location.apply(lambda loclist: loclist['address1'])
yelp_gendf_marlow[['alias', 'name', 'url', 'review_count', 'rating', 'location1', 'price']]

# Optional: Restrict to cols that are just strings
#yelp_stronly_marlow = [clean_yelp_json(one_b) for one_b in yelp_genjson_marlow['businesses']]
#yelp_stronly_marlow_df = pd.concat(yelp_stronly_marlow)

#yelp_stronly_marlow_df.head(10)
# Out:
# <Response [200]>
#                                              alias  \
# 0              mill-village-country-store-stoddard
# 1                      hilltop-kitchen-harrisville
# 2   auntie-ts-roadside-grill-and-catering-stoddard
# 3                                 kirbys-q-alstead
# 4              washington-general-store-washington
# 5                         macdougalls-tavern-keene
# 6                          lighthouse-westmoreland
# 7                           pizza-down-under-keene
# 8                            guru-food-truck-keene
# 9                              elm-st-market-keene
# 10                                 pizza-pie-keene
# 11                 feng-tong-chinese-kitchen-keene
#
#                                     name  \
# 0             Mill Village Country Store
# 1                        Hilltop Kitchen
# 2   Auntie T's Roadside Grill & Catering
# 3                              Kirby's Q
# 4               Washington General Store
# 5                    MacDougall's Tavern
# 6                             Lighthouse
# 7                       Pizza Down Under
# 8                        Guru Food Truck
# 9                          Elm St Market
# 10                             Pizza Pie
# 11             Feng Tong Chinese Kitchen
#
#                                                   url  review_count  rating  \
# 0   https://www.yelp.com/biz/mill-village-country-...            13     4.5
# 1   https://www.yelp.com/biz/hilltop-kitchen-harri...             3     5.0
# 2   https://www.yelp.com/biz/auntie-ts-roadside-gr...             8     4.5
# 3   https://www.yelp.com/biz/kirbys-q-alstead?adju...            25     4.5
# 4   https://www.yelp.com/biz/washington-general-st...            14     4.0
# 5   https://www.yelp.com/biz/macdougalls-tavern-ke...             5     4.5
# 6   https://www.yelp.com/biz/lighthouse-westmorela...             0     0.0
# 7   https://www.yelp.com/biz/pizza-down-under-keen...            20     4.0
# 8   https://www.yelp.com/biz/guru-food-truck-keene...             1     5.0
# 9   https://www.yelp.com/biz/elm-st-market-keene?a...             8     5.0
# 10  https://www.yelp.com/biz/pizza-pie-keene?adjus...            31     3.0
# 11  https://www.yelp.com/biz/feng-tong-chinese-kit...            24     3.0
#
#                 location1 price
# 0           984 Rte 123 N   NaN
# 1   184 Aldworth Manor Rd   NaN
# 2               475 Rte 9   NaN
# 3            163 River St    $$
# 4            29 N Main St   $$$
# 5            630 Park Ave     $
# 6            719 Route 12   NaN
# 7            800 Park Ave     $
# 8                    None   NaN
# 9              130 Elm St     $
# 10           815 Court St     $
# 11           650 Park Ave   NaN

# %%
# Get one random business
one_biz = yelp_stronly_df.sample()[['name', 'id']]
one_biz
# Out:
#                                                    name  \
# Ecdu5qYM09F647Uoez99vg  Ramunto's Brick & Brew Pizzeria
#
#                                             id
# Ecdu5qYM09F647Uoez99vg  Ecdu5qYM09F647Uoez99vg

# %%
url = "https://api.yelp.com/v3/businesses/Ecdu5qYM09F647Uoez99vg/reviews?"
# header = {‘Authorization’: f”Bearer {API_KEY}""}
response = requests.get(url, headers=header)
print(response.text)
# Out:
# {"reviews": [{"id": "UpqByKb8iBIFzYvFmvtt0A", "url": "https://www.yelp.com/biz/ramuntos-brick-and-brew-pizzeria-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=UpqByKb8iBIFzYvFmvtt0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w", "text": "Best pizza ever from this townie. Even other towns nearby... still can't get me to fully change my mind on how this place has the best sauce, pies, and noms...", "rating": 5, "time_created": "2023-08-08 06:53:00", "user": {"id": "kgAiZU60RefGdjkeRdi0pA", "profile_url": "https://www.yelp.com/user_details?userid=kgAiZU60RefGdjkeRdi0pA", "image_url": "https://s3-media2.fl.yelpcdn.com/photo/lLzLXgaHEtgaPwhPVfs74g/o.jpg", "name": "Mia A."}}, {"id": "Yxj8gWX2isGf0-DVBPq67A", "url": "https://www.yelp.com/biz/ramuntos-brick-and-brew-pizzeria-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=Yxj8gWX2isGf0-DVBPq67A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w", "text": "Food's great. I've never eaten in the restaurant but I've been inside to pick stuff up, and it looks like a pleasant place. Remarkably good menu selection...", "rating": 5, "time_created": "2023-07-16 06:33:50", "user": {"id": "u4xo8pAidfxkySAqdLCMzw", "profile_url": "https://www.yelp.com/user_details?userid=u4xo8pAidfxkySAqdLCMzw", "image_url": "https://s3-media2.fl.yelpcdn.com/photo/Hgwrx7swzNs7m28FBwq26Q/o.jpg", "name": "Izzy T."}}, {"id": "v7yO_1BBXGmVtPIYM2Pt2g", "url": "https://www.yelp.com/biz/ramuntos-brick-and-brew-pizzeria-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=v7yO_1BBXGmVtPIYM2Pt2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w", "text": "Unfortunately, I have had a few shockingly bad service experiences here. I don't appreciate being treated like a nuisance when I'm just ordering my food. I...", "rating": 1, "time_created": "2023-08-14 16:55:57", "user": {"id": "QqgErTzfEOH5KdcW387Mow", "profile_url": "https://www.yelp.com/user_details?userid=QqgErTzfEOH5KdcW387Mow", "image_url": null, "name": "D. W."}}], "total": 135, "possible_languages": ["en"]}

# %%
response.text
# Out:
# '{"reviews": [{"id": "8I8ALslMWvOQmd7AnO4N8w", "url": "https://www.yelp.com/biz/the-shed-restaurant-plainview-plainview?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=8I8ALslMWvOQmd7AnO4N8w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w", "text": "I LOVE THE SHED!\\n\\nAny location doesn\'t matter my experience has blown me away and left me satisfied.\\n\\nThe grilled chicken entree was better than my grilled...", "rating": 5, "time_created": "2023-09-23 14:26:01", "user": {"id": "HOxaVDup_Ctag_npGDdF0A", "profile_url": "https://www.yelp.com/user_details?userid=HOxaVDup_Ctag_npGDdF0A", "image_url": "https://s3-media3.fl.yelpcdn.com/photo/P78IjRv3JfpOcjE0T1dgqw/o.jpg", "name": "Emily B."}}, {"id": "sPyEsPtJz48wyOd3DIrtGA", "url": "https://www.yelp.com/biz/the-shed-restaurant-plainview-plainview?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=sPyEsPtJz48wyOd3DIrtGA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w", "text": "A small group of friends and I did outdoor dining here. The set up was lovely and interior was spacious, with white brick walls and beautiful artistic mural...", "rating": 4, "time_created": "2023-10-09 14:54:07", "user": {"id": "RJH925_Ci598EuRx9JoGwA", "profile_url": "https://www.yelp.com/user_details?userid=RJH925_Ci598EuRx9JoGwA", "image_url": "https://s3-media2.fl.yelpcdn.com/photo/24yQpxA_Omp7j4NFVyZp2A/o.jpg", "name": "Kathy X."}}, {"id": "kQkiDuuxQI6yLH59FiGuxw", "url": "https://www.yelp.com/biz/the-shed-restaurant-plainview-plainview?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=kQkiDuuxQI6yLH59FiGuxw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w", "text": "I always go right when they open to beat the lunch crowd, especially since they do not take reservations. Some servers are better than others and there is...", "rating": 4, "time_created": "2023-09-26 07:12:01", "user": {"id": "55DO2OSV4-nZhy0fvyxxbA", "profile_url": "https://www.yelp.com/user_details?userid=55DO2OSV4-nZhy0fvyxxbA", "image_url": "https://s3-media4.fl.yelpcdn.com/photo/ZDVfT1A7YgqDA5H8ddq_Ag/o.jpg", "name": "Annie Y."}}], "total": 248, "possible_languages": ["en"]}'

# %%
# look at reviews of business with this id
base_url_reviews = f'https://api.yelp.com/v3/businesses/{one_biz.id[0]}/reviews'
yelp_genquery_reviews = (base_url_reviews)

## use requests to call the API
header = {'Authorization': f"Bearer {API_KEY}"}
yelp_genresp_reviews = requests.get(yelp_genquery_reviews, headers = header)
yelp_genresp_reviews

## then, look at structure of response
yelp_genjson_reviews = yelp_genresp_reviews.json()
yelp_genjson_reviews
# Out:
# <Response [200]>
# {'reviews': [{'id': 'UpqByKb8iBIFzYvFmvtt0A',
#    'url': 'https://www.yelp.com/biz/ramuntos-brick-and-brew-pizzeria-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=UpqByKb8iBIFzYvFmvtt0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'text': "Best pizza ever from this townie. Even other towns nearby... still can't get me to fully change my mind on how this place has the best sauce, pies, and noms...",
#    'rating': 5,
#    'time_created': '2023-08-08 06:53:00',
#    'user': {'id': 'kgAiZU60RefGdjkeRdi0pA',
#     'profile_url': 'https://www.yelp.com/user_details?userid=kgAiZU60RefGdjkeRdi0pA',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/lLzLXgaHEtgaPwhPVfs74g/o.jpg',
#     'name': 'Mia A.'}},
#   {'id': 'Yxj8gWX2isGf0-DVBPq67A',
#    'url': 'https://www.yelp.com/biz/ramuntos-brick-and-brew-pizzeria-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=Yxj8gWX2isGf0-DVBPq67A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'text': "Food's great. I've never eaten in the restaurant but I've been inside to pick stuff up, and it looks like a pleasant place. Remarkably good menu selection...",
#    'rating': 5,
#    'time_created': '2023-07-16 06:33:50',
#    'user': {'id': 'u4xo8pAidfxkySAqdLCMzw',
#     'profile_url': 'https://www.yelp.com/user_details?userid=u4xo8pAidfxkySAqdLCMzw',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/Hgwrx7swzNs7m28FBwq26Q/o.jpg',
#     'name': 'Izzy T.'}},
#   {'id': 'v7yO_1BBXGmVtPIYM2Pt2g',
#    'url': 'https://www.yelp.com/biz/ramuntos-brick-and-brew-pizzeria-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=v7yO_1BBXGmVtPIYM2Pt2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'text': "Unfortunately, I have had a few shockingly bad service experiences here. I don't appreciate being treated like a nuisance when I'm just ordering my food. I...",
#    'rating': 1,
#    'time_created': '2023-08-14 16:55:57',
#    'user': {'id': 'QqgErTzfEOH5KdcW387Mow',
#     'profile_url': 'https://www.yelp.com/user_details?userid=QqgErTzfEOH5KdcW387Mow',
#     'image_url': None,
#     'name': 'D. W.'}}],
#  'total': 135,
#  'possible_languages': ['en']}

# %%
yelp_genjson_reviews['reviews']
# Out:
# [{'id': 'UpqByKb8iBIFzYvFmvtt0A',
#   'url': 'https://www.yelp.com/biz/ramuntos-brick-and-brew-pizzeria-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=UpqByKb8iBIFzYvFmvtt0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'text': "Best pizza ever from this townie. Even other towns nearby... still can't get me to fully change my mind on how this place has the best sauce, pies, and noms...",
#   'rating': 5,
#   'time_created': '2023-08-08 06:53:00',
#   'user': {'id': 'kgAiZU60RefGdjkeRdi0pA',
#    'profile_url': 'https://www.yelp.com/user_details?userid=kgAiZU60RefGdjkeRdi0pA',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/lLzLXgaHEtgaPwhPVfs74g/o.jpg',
#    'name': 'Mia A.'}},
#  {'id': 'Yxj8gWX2isGf0-DVBPq67A',
#   'url': 'https://www.yelp.com/biz/ramuntos-brick-and-brew-pizzeria-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=Yxj8gWX2isGf0-DVBPq67A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'text': "Food's great. I've never eaten in the restaurant but I've been inside to pick stuff up, and it looks like a pleasant place. Remarkably good menu selection...",
#   'rating': 5,
#   'time_created': '2023-07-16 06:33:50',
#   'user': {'id': 'u4xo8pAidfxkySAqdLCMzw',
#    'profile_url': 'https://www.yelp.com/user_details?userid=u4xo8pAidfxkySAqdLCMzw',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/Hgwrx7swzNs7m28FBwq26Q/o.jpg',
#    'name': 'Izzy T.'}},
#  {'id': 'v7yO_1BBXGmVtPIYM2Pt2g',
#   'url': 'https://www.yelp.com/biz/ramuntos-brick-and-brew-pizzeria-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=v7yO_1BBXGmVtPIYM2Pt2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#   'text': "Unfortunately, I have had a few shockingly bad service experiences here. I don't appreciate being treated like a nuisance when I'm just ordering my food. I...",
#   'rating': 1,
#   'time_created': '2023-08-14 16:55:57',
#   'user': {'id': 'QqgErTzfEOH5KdcW387Mow',
#    'profile_url': 'https://www.yelp.com/user_details?userid=QqgErTzfEOH5KdcW387Mow',
#    'image_url': None,
#    'name': 'D. W.'}}]

# %%
yelp_genjson_reviews
# Out:
# {'reviews': [{'id': 'UpqByKb8iBIFzYvFmvtt0A',
#    'url': 'https://www.yelp.com/biz/ramuntos-brick-and-brew-pizzeria-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=UpqByKb8iBIFzYvFmvtt0A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'text': "Best pizza ever from this townie. Even other towns nearby... still can't get me to fully change my mind on how this place has the best sauce, pies, and noms...",
#    'rating': 5,
#    'time_created': '2023-08-08 06:53:00',
#    'user': {'id': 'kgAiZU60RefGdjkeRdi0pA',
#     'profile_url': 'https://www.yelp.com/user_details?userid=kgAiZU60RefGdjkeRdi0pA',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/lLzLXgaHEtgaPwhPVfs74g/o.jpg',
#     'name': 'Mia A.'}},
#   {'id': 'Yxj8gWX2isGf0-DVBPq67A',
#    'url': 'https://www.yelp.com/biz/ramuntos-brick-and-brew-pizzeria-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=Yxj8gWX2isGf0-DVBPq67A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'text': "Food's great. I've never eaten in the restaurant but I've been inside to pick stuff up, and it looks like a pleasant place. Remarkably good menu selection...",
#    'rating': 5,
#    'time_created': '2023-07-16 06:33:50',
#    'user': {'id': 'u4xo8pAidfxkySAqdLCMzw',
#     'profile_url': 'https://www.yelp.com/user_details?userid=u4xo8pAidfxkySAqdLCMzw',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/Hgwrx7swzNs7m28FBwq26Q/o.jpg',
#     'name': 'Izzy T.'}},
#   {'id': 'v7yO_1BBXGmVtPIYM2Pt2g',
#    'url': 'https://www.yelp.com/biz/ramuntos-brick-and-brew-pizzeria-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=v7yO_1BBXGmVtPIYM2Pt2g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'text': "Unfortunately, I have had a few shockingly bad service experiences here. I don't appreciate being treated like a nuisance when I'm just ordering my food. I...",
#    'rating': 1,
#    'time_created': '2023-08-14 16:55:57',
#    'user': {'id': 'QqgErTzfEOH5KdcW387Mow',
#     'profile_url': 'https://www.yelp.com/user_details?userid=QqgErTzfEOH5KdcW387Mow',
#     'image_url': None,
#     'name': 'D. W.'}}],
#  'total': 135,
#  'possible_languages': ['en']}

# %%
## turn JSON into usable data (DF)
yelp_gendf_reviews = pd.DataFrame(yelp_genjson_reviews['reviews'])
yelp_gendf_reviews
# Out:
#                        id                                                url  \
# 0  ZKw3pgptzE3aKiKmwFLK1Q  https://www.yelp.com/biz/sushiya-hanover-2?adj...
# 1  nzGzOK01t_DztjuYGwB4SQ  https://www.yelp.com/biz/sushiya-hanover-2?adj...
# 2  xfBpLVOxGF9UZAoe8wQpBw  https://www.yelp.com/biz/sushiya-hanover-2?adj...
#
#                                                 text  rating  \
# 0  Just had an phenomenal meal here and look forw...       5
# 1  This restaurant is now takeout only. The sushi...       3
# 2  Ordered takeout for 6 rolls. All of them taste...       4
#
#           time_created                                               user
# 0  2022-08-25 19:19:55  {'id': '76gvqovFuTpEoOHysjbY6w', 'profile_url'...
# 1  2022-10-17 18:15:08  {'id': 'trIbciU6PXfiXr0BYz0DQw', 'profile_url'...
# 2  2021-10-14 19:20:23  {'id': 'Imrkj1Ywx5RVNDmDh9AFcw', 'profile_url'...
