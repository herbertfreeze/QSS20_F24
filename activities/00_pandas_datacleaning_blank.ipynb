# %% [markdown]
# ## 0. Load imports

# %%
## imports
import pandas as pd
import numpy as np


## print multiple things from same cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## 0. Load data

# %%
## load data on 2020 crimes in DC
df = dc_crim_2020 = pd.read_csv("https://opendata.arcgis.com/datasets/f516e0dd7b614b088ad781b0c4002331_2.csv")
dc_crim_2020.head()
dc_crim_2020.shape
dc_crim_2020.info()
# Out:
#            X          Y       CCN              REPORT_DAT     SHIFT  METHOD  \
# 0 -77.033293  38.919188  20118678  2020/08/20 00:24:28+00   EVENING  OTHERS
# 1 -77.005401  38.879914  20023507  2020/02/08 05:59:18+00  MIDNIGHT  OTHERS
# 2 -76.949648  38.865420  20090091  2020/06/19 09:34:15+00  MIDNIGHT  OTHERS
# 3 -77.027959  38.961979  20048262  2020/03/20 04:20:47+00  MIDNIGHT  OTHERS
# 4 -76.945923  38.900875  20050930  2020/03/26 04:28:40+00  MIDNIGHT  OTHERS
#
#                OFFENSE                                      BLOCK     XBLOCK  \
# 0          THEFT/OTHER           1400 - 1499 BLOCK OF W STREET NW  397113.00
# 1  MOTOR VEHICLE THEFT       800 - 899 BLOCK OF NEW JERSEY AVE SE  399531.54
# 2          THEFT/OTHER  1800 - 1899 BLOCK OF FORT DAVIS STREET SE  404370.00
# 3         THEFT F/AUTO     5900 - 5999 BLOCK OF GEORGIA AVENUE NW  397577.00
# 4         THEFT F/AUTO    740 - 899 BLOCK OF KENILWORTH AVENUE NE  404691.00
#
#       YBLOCK  ...  BLOCK_GROUP CENSUS_TRACT  VOTING_PRECINCT   LATITUDE  \
# 0  139035.00  ...     004300 2       4300.0      Precinct 22  38.919180
# 1  134674.78  ...     007203 3       7203.0     Precinct 131  38.879907
# 2  133067.00  ...     009902 2       9902.0     Precinct 110  38.865412
# 3  143785.00  ...     001901 1       1901.0      Precinct 58  38.961971
# 4  137003.00  ...     009602 2       9602.0     Precinct 100  38.900868
#
#    LONGITUDE                 BID              START_DATE  \
# 0 -77.033291                 NaN  2020/08/08 00:24:44+00
# 1 -77.005399  CAPITOL RIVERFRONT  2020/02/08 01:43:11+00
# 2 -76.949646                 NaN  2020/06/16 15:00:02+00
# 3 -77.027957                 NaN  2020/03/19 23:22:40+00
# 4 -76.945921                 NaN  2020/03/25 20:00:23+00
#
#                  END_DATE   OBJECTID  OCTO_RECORD_ID
# 0  2020/08/20 00:24:46+00  596090405             NaN
# 1  2020/02/08 01:53:11+00  596090413             NaN
# 2  2020/06/18 16:00:22+00  596090448             NaN
# 3  2020/03/20 00:49:00+00  596090460             NaN
# 4  2020/03/26 04:10:44+00  596090461             NaN
#
# [5 rows x 25 columns]
# (27931, 25)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27931 entries, 0 to 27930
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   X                     27931 non-null  float64
#  1   Y                     27931 non-null  float64
#  2   CCN                   27931 non-null  int64
#  3   REPORT_DAT            27931 non-null  object
#  4   SHIFT                 27931 non-null  object
#  5   METHOD                27931 non-null  object
#  6   OFFENSE               27931 non-null  object
#  7   BLOCK                 27931 non-null  object
#  8   XBLOCK                27931 non-null  float64
#  9   YBLOCK                27931 non-null  float64
#  10  WARD                  27931 non-null  int64
#  11  ANC                   27931 non-null  object
#  12  DISTRICT              27902 non-null  float64
#  13  PSA                   27896 non-null  float64
#  14  NEIGHBORHOOD_CLUSTER  27931 non-null  object
#  15  BLOCK_GROUP           27930 non-null  object
#  16  CENSUS_TRACT          27930 non-null  float64
#  17  VOTING_PRECINCT       27931 non-null  object
#  18  LATITUDE              27931 non-null  float64
#  19  LONGITUDE             27931 non-null  float64
#  20  BID                   4658 non-null   object
#  21  START_DATE            27931 non-null  object
#  22  END_DATE              24850 non-null  object
#  23  OBJECTID              27931 non-null  int64
#  24  OCTO_RECORD_ID        0 non-null      float64
# dtypes: float64(10), int64(3), object(12)
# memory usage: 5.3+ MB

# %%
df.X
# Out:
# 0       -77.033293
# 1       -77.005401
# 2       -76.949648
# 3       -77.027959
# 4       -76.945923
#            ...
# 27926   -76.974974
# 27927   -77.031955
# 27928   -77.020926
# 27929   -77.001328
# 27930   -77.053321
# Name: X, Length: 27931, dtype: float64

# %%
df[ df.METHOD.str.contains("GUN") ] [["METHOD"]]
# Out:
#       METHOD
# 17       GUN
# 24       GUN
# 58       GUN
# 78       GUN
# 91       GUN
# ...      ...
# 27861    GUN
# 27874    GUN
# 27891    GUN
# 27892    GUN
# 27895    GUN
#
# [2034 rows x 1 columns]

# %%
df[ (df.WARD == 1) ][["WARD", "X", "Y"]]
# Out:
#        WARD          X          Y
# 0         1 -77.033293  38.919188
# 7         1 -77.038004  38.930348
# 12        1 -77.041588  38.925816
# 13        1 -77.046310  38.915409
# 16        1 -77.042956  38.917825
# ...     ...        ...        ...
# 27904     1 -77.025199  38.920208
# 27910     1 -77.024218  38.918073
# 27917     1 -77.040091  38.929690
# 27920     1 -77.046026  38.923238
# 27927     1 -77.031955  38.918648
#
# [3542 rows x 3 columns]

# %%
df[ (df.X > -77) & (df.Y < 40) ]
# Out:
#                X          Y       CCN              REPORT_DAT     SHIFT  \
# 2     -76.949648  38.865420  20090091  2020/06/19 09:34:15+00  MIDNIGHT
# 4     -76.945923  38.900875  20050930  2020/03/26 04:28:40+00  MIDNIGHT
# 5     -76.961919  38.931312  20400101  2020/01/17 20:05:59+00   EVENING
# 6     -76.999011  38.923715  20117957  2020/08/18 16:11:37+00       DAY
# 8     -76.986479  38.842414  20172839  2020/12/05 07:37:01+00  MIDNIGHT
# ...          ...        ...       ...                     ...       ...
# 27915 -76.980077  38.917191  20047796  2020/03/18 23:47:50+00   EVENING
# 27916 -76.952902  38.919854  20012693  2020/01/22 02:34:31+00   EVENING
# 27918 -76.996824  38.825397  20033610  2020/02/25 00:15:41+00   EVENING
# 27922 -76.933251  38.902932  20120775  2020/08/24 11:29:25+00       DAY
# 27926 -76.974974  38.868554  20013962  2020/01/24 04:18:43+00  MIDNIGHT
#
#        METHOD              OFFENSE                                      BLOCK  \
# 2      OTHERS          THEFT/OTHER  1800 - 1899 BLOCK OF FORT DAVIS STREET SE
#  23.0883756068405,
#  23.015324052350906,
#  23.009093999257104,
#  22.931019219057305,
#  22.981513012614897,
#  22.959116582078295,
#  22.968789889078593,
#  23.003824696652003,
#  22.971500480947,
#  22.977038861422002,
#  23.001542582462704,
#  22.974609442383695,
#  22.970368075809304,
#  23.058577350477506,
#  23.024566086272998,
#  22.9808151592881,
#  22.972143625252997,
#  23.047222261242695,
#  22.961594571294896,
#  23.012925585912996,
#  22.967263556754503,
#  23.021208988778,
#  23.0214764401005,
#  22.971856900367797,
#  23.012011857688904,
#  22.986338630242003,
#  22.967707390661303,
#  22.9284333572719,
#  22.950207916535504,
#  23.035953596839093,
#  22.957045594077798,
#  22.946267262658594,
#  22.935546507987794,
#  22.972954144322102,
#  22.931827511891697,
#  22.904206956235498,
#  22.979085038369604,
#  23.0009552588551,
#  22.941915489367005,
#  22.975010921669295,
#  22.966356412116596,
#  22.9603274429806,
#  22.963518789194893,
#  23.0008736735725,
#  23.048629815910104,
#  23.0770444166086,
#  22.972444970446404,
#  22.977252620085807,
#  23.021861831520994,
#  22.955818168844402,
#  23.042472079042398,
#  22.9614902467644,
#  23.007452116447297,
#  22.949833262969307,
#  22.9587072480697,
#  23.0050375087296,
#  23.017982258268603,
#  23.006236356817496,
#  22.982438686129697,
#  ...]

# %%
# %%time
df.X + 100
# Out:
# CPU times: user 1.69 ms, sys: 138 µs, total: 1.83 ms
# Wall time: 1.79 ms
# 0        23.027774
# 1        23.027349
# 2        22.976019
# 3        22.969212
# 4        22.998247
#            ...
# 27926    23.024126
# 27927    22.943827
# 27928    22.969722
# 27929    22.976534
# 27930    23.051273
# Name: X, Length: 27931, dtype: float64

# %%
for i,ddf in df.groupby("WARD"):
    if i == 2:
        break
    
ddf.X.mean()
# Out:
# -77.03895868572333

# %%
for i,r in enumerate(df.X):
    print(i,r)
    if i==10:
        break
# Out:
# 0 -76.9722256798901
# 1 -76.9726506441451
# 2 -77.0239810457319
# 3 -77.0307876903426
# 4 -77.0017526414979
# 5 -77.0684842540747
# 6 -76.9864810753013
# 7 -76.9870315010185
# 8 -77.0205331614394
# 9 -77.0280891647109
# 10 -76.9772701309355

# %%
for r in df.X.iloc[:10]:
    print(r)
# Out:
# -76.9722256798901
# -76.9726506441451
# -77.0239810457319
# -77.0307876903426
# -77.0017526414979
# -77.0684842540747
# -76.9864810753013
# -76.9870315010185
# -77.0205331614394
# -77.0280891647109

# %% [markdown]
# ## 1. Aggregation

# %% [markdown]
# ### Example of grouping by one variable and doing one aggregation
#
# **Task**: find and print the number of unique offense types (`OFFENSE`) by ward (`WARD`)

# %%
df1 = df.groupby("WARD")
df2 = df1.OFFENSE.unique()
df3 = df2.apply(len)
print(df3)
# Out:
# WARD
# 1    9
# 2    9
# 3    8
# 4    8
# 5    9
# 6    9
# 7    9
# 8    9
# Name: OFFENSE, dtype: int64

# %%
df.groupby("WARD")["X"].nunique()
# Out:
# WARD
# 1   -77.031256
# 2   -77.038959
# 3   -77.075320
# 4   -77.024905
# 5   -76.989451
# 6   -77.001175
# 7   -76.947402
# 8   -76.988986
# Name: X, dtype: float64

# %%
df2
# Out:
# WARD
# 1    [THEFT F/AUTO, ROBBERY, THEFT/OTHER, ASSAULT W...
# 2    [THEFT F/AUTO, THEFT/OTHER, BURGLARY, ROBBERY,...
# 3    [THEFT F/AUTO, THEFT/OTHER, MOTOR VEHICLE THEF...
# 4    [THEFT/OTHER, THEFT F/AUTO, MOTOR VEHICLE THEF...
# 5    [THEFT/OTHER, THEFT F/AUTO, MOTOR VEHICLE THEF...
# 6    [THEFT/OTHER, ASSAULT W/DANGEROUS WEAPON, THEF...
# 7    [THEFT/OTHER, THEFT F/AUTO, MOTOR VEHICLE THEF...
# 8    [HOMICIDE, THEFT F/AUTO, THEFT/OTHER, MOTOR VE...
# Name: OFFENSE, dtype: object

# %%
", ".join( ["a", "b", "c"]  )
# Out:
# 'a, b, c'

# %%
df
# Out:
#                X          Y       CCN              REPORT_DAT     SHIFT  \
# 0     -76.972226  38.854086  10147537  2020/12/21 05:00:00+00  MIDNIGHT
# 1     -76.972651  38.857491  10251445  2020/09/11 04:00:00+00  MIDNIGHT
# 2     -77.023981  38.900345      5370  2020/01/17 02:39:05+00   EVENING
# 3     -77.030788  38.911874     16641  2020/01/28 05:14:39+00  MIDNIGHT
# 4     -77.001753  38.821632  18048023  2020/10/21 04:00:00+00  MIDNIGHT
# ...          ...        ...       ...                     ...       ...
# 27926 -76.975874  38.898804  20164210  2020/11/17 04:56:08+00  MIDNIGHT
# 27927 -77.056173  38.980102  20165984  2020/11/20 22:07:20+00   EVENING
# 27928 -77.030278  38.959771  20166277  2020/11/21 08:35:50+00  MIDNIGHT
# 27929 -77.023466  38.911795  20166597  2020/11/22 01:02:20+00   EVENING
# 27930 -76.948727  38.864537  20108439  2020/07/29 23:18:00+00   EVENING
#
#        METHOD                     OFFENSE  \
# 0      OTHERS                    HOMICIDE
# 1         GUN                    HOMICIDE
# 2      OTHERS                THEFT F/AUTO
# 3      OTHERS                THEFT F/AUTO
# 4      OTHERS                    HOMICIDE
# ...       ...                         ...
# 27926     GUN  ASSAULT W/DANGEROUS WEAPON
# 27927  OTHERS                THEFT F/AUTO
# 27928  OTHERS         MOTOR VEHICLE THEFT
# 27929  OTHERS                THEFT F/AUTO
# 27930  OTHERS                 THEFT/OTHER
#
#                                              BLOCK    XBLOCK    YBLOCK  ...  \
# 0          2300 - 2499 BLOCK OF HARTFORD STREET SE  402411.0  131808.0  ...
# 1             2300 - 2399 BLOCK OF AINGER PLACE SE  402374.0  132186.0  ...
# 2                 800 - 899 BLOCK OF 9TH STREET NW  397920.0  136943.0  ...
# 3          1300 - 1399 BLOCK OF CORCORAN STREET NW  397330.0  138223.0  ...
# 4        4600 - 4799 BLOCK OF SOUTH CAPITOL STREET  399848.0  128205.0  ...
# ...                                            ...       ...       ...  ...
# 27926         1900 - 1999 BLOCK OF BENNING ROAD NE  402093.0  136772.0  ...
# 27927         6818  - 6899 BLOCK OF 32ND STREET NW  395133.0  145798.0  ...
# 27928     5729  - 5799 BLOCK OF COLORADO AVENUE NW  397376.0  143540.0  ...
# 27929    800 - 899 BLOCK OF RHODE ISLAND AVENUE NW  397965.0  138214.0  ...
# 27930  3901 - 3998 BLOCK OF PENNSYLVANIA AVENUE SE  404450.0  132969.0  ...
#
#        BLOCK_GROUP CENSUS_TRACT  VOTING_PRECINCT   LATITUDE  LONGITUDE  \
# 0         007408 2       7408.0     Precinct 115  38.854078 -76.972223
# 1         007502 1       7502.0     Precinct 134  38.857483 -76.972648
# 2         005802 5       5802.0     Precinct 129  38.900337 -77.023979
# 3         005001 2       5001.0      Precinct 16  38.911866 -77.030785
# 4         009811 1       9811.0     Precinct 125  38.821624 -77.001750
# ...            ...          ...              ...        ...        ...
# 27926     007903 1       7903.0      Precinct 80  38.898797 -76.975872
# 27927     001500 1       1500.0      Precinct 51  38.980095 -77.056171
# 27928     002001 1       2001.0      Precinct 53  38.959763 -77.030275
# 27929     004901 1       4901.0      Precinct 21  38.911787 -77.023464
# 27930     007603 1       7603.0     Precinct 110  38.864529 -76.948725
#
#             BID              START_DATE                END_DATE   OBJECTID  \
# 0           NaN  2010/10/10 02:00:00+00                     NaN  591661247
# 1           NaN  2010/09/02 04:00:00+00  2010/09/02 04:00:00+00  591661253
# 2      DOWNTOWN  2020/01/11 02:48:51+00  2020/01/17 02:48:54+00  591661257
# 3           NaN  2020/01/28 05:14:58+00  2020/01/28 05:15:02+00  591661258
# 4           NaN  2018/03/26 08:40:06+00  2018/03/26 10:04:44+00  591667619
# ...         ...                     ...                     ...        ...
# 27926       NaN  2020/11/17 03:15:19+00  2020/11/17 03:22:54+00  592213441
# 27927       NaN  2020/11/19 19:45:47+00  2020/11/19 20:00:49+00  592213442
# 27928       NaN  2020/11/21 06:06:45+00                     NaN  592213443
# 27929       NaN  2020/11/20 22:00:35+00  2020/11/21 22:30:51+00  592213444
# 27930       NaN  2020/07/22 14:11:29+00  2020/07/22 14:20:44+00  592213515
#
#        OCTO_RECORD_ID
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 27926             NaN
# 27927             NaN
# 27928             NaN
# 27929             NaN
# 27930             NaN
#
# [27931 rows x 25 columns]

# %% [markdown]
# ### Example of grouping by one variable and providing two summaries of the same variable
#
# **Task**: previous showed number of offenses by ward but want to find out content of offenses in each ward; create an aggregation that summarizes both the number of unique offenses by ward and what those offenses are -- for instance, by pasting the unique offenses in that ward separated by the ";" (e.g., Theft; Burglary;...)
#
# *Hint*: you can use the join command to paste together a list separated by some delimiter.
#     - The syntax, if we are using the comma delimiter, is: ", ".join(nameoflist)

# %%
offenses_summary = df.groupby('WARD').agg(
    unique_offense_count=('OFFENSE', 'nunique'),
    unique_offenses=('OFFENSE', lambda x: "; ".join(x.unique()))
).reset_index()
offenses_summary
# Out:
#    WARD  unique_offense_count  \
# 0     1                     9
# 1     2                     9
# 2     3                     8
# 3     4                     8
# 4     5                     9
# 5     6                     9
# 6     7                     9
# 7     8                     9
#
#                                      unique_offenses
# 0  THEFT F/AUTO; ROBBERY; THEFT/OTHER; ASSAULT W/...
# 1  THEFT F/AUTO; THEFT/OTHER; BURGLARY; ROBBERY; ...
# 2  THEFT F/AUTO; THEFT/OTHER; MOTOR VEHICLE THEFT...
# 3  THEFT/OTHER; THEFT F/AUTO; MOTOR VEHICLE THEFT...
# 4  THEFT/OTHER; THEFT F/AUTO; MOTOR VEHICLE THEFT...
# 5  THEFT/OTHER; ASSAULT W/DANGEROUS WEAPON; THEFT...
# 6  THEFT/OTHER; THEFT F/AUTO; MOTOR VEHICLE THEFT...
# 7  HOMICIDE; THEFT F/AUTO; THEFT/OTHER; MOTOR VEH...

# %%
for i, ddf in df.groupby("WARD"):
    break

# %%
", ".join( ddf["OFFENSE"].unique() )
# Out:
# 'THEFT F/AUTO, ROBBERY, THEFT/OTHER, ASSAULT W/DANGEROUS WEAPON, MOTOR VEHICLE THEFT, BURGLARY, HOMICIDE, SEX ABUSE, ARSON'

# %%
def get_unique_offenses(x):
    y = x.unique()
    return ", ".join(y)

get_unique_offenses(ddf["OFFENSE"])
# Out:
# 'THEFT F/AUTO, ROBBERY, THEFT/OTHER, ASSAULT W/DANGEROUS WEAPON, MOTOR VEHICLE THEFT, BURGLARY, HOMICIDE, SEX ABUSE, ARSON'

# %%
df.groupby("WARD")["OFFENSE"].agg(get_unique_offenses)
# Out:
# WARD
# 1    THEFT F/AUTO, ROBBERY, THEFT/OTHER, ASSAULT W/...
# 2    THEFT F/AUTO, THEFT/OTHER, BURGLARY, ROBBERY, ...
# 3    THEFT F/AUTO, THEFT/OTHER, MOTOR VEHICLE THEFT...
# 4    THEFT/OTHER, THEFT F/AUTO, MOTOR VEHICLE THEFT...
# 5    THEFT/OTHER, THEFT F/AUTO, MOTOR VEHICLE THEFT...
# 6    THEFT/OTHER, ASSAULT W/DANGEROUS WEAPON, THEFT...
# 7    THEFT/OTHER, THEFT F/AUTO, MOTOR VEHICLE THEFT...
# 8    HOMICIDE, THEFT F/AUTO, THEFT/OTHER, MOTOR VEH...
# Name: OFFENSE, dtype: object

# %%
offenses_summary = df.groupby('WARD').agg(
    {
        "OFFENSE": ["nunique", get_unique_offenses]
    }
)
offenses_summary.reset_index()
# Out:
#   WARD OFFENSE
#        nunique                                get_unique_offenses
# 0    1       9  THEFT F/AUTO, ROBBERY, THEFT/OTHER, ASSAULT W/...
# 1    2       9  THEFT F/AUTO, THEFT/OTHER, BURGLARY, ROBBERY, ...
# 2    3       8  THEFT F/AUTO, THEFT/OTHER, MOTOR VEHICLE THEFT...
# 3    4       8  THEFT/OTHER, THEFT F/AUTO, MOTOR VEHICLE THEFT...
# 4    5       9  THEFT/OTHER, THEFT F/AUTO, MOTOR VEHICLE THEFT...
# 5    6       9  THEFT/OTHER, ASSAULT W/DANGEROUS WEAPON, THEFT...
# 6    7       9  THEFT/OTHER, THEFT F/AUTO, MOTOR VEHICLE THEFT...
# 7    8       9  HOMICIDE, THEFT F/AUTO, THEFT/OTHER, MOTOR VEH...

# %% [markdown]
# ### Example of grouping by two variables
#
# **Task**: group by ward (`WARD`) and police shift (`SHIFT`) and find the offense that is most common in that ward and shift

# %%
df.OFFENSE.mode()
# Out:
# 0    THEFT/OTHER
# Name: OFFENSE, dtype: object

# %%
df.groupby(["WARD", "SHIFT"]).agg(
    {"OFFENSE" : lambda x: x.mode() }
    )
# Out:
#                                   OFFENSE
# WARD SHIFT
# 1    DAY                      THEFT/OTHER
#      EVENING                  THEFT/OTHER
#      MIDNIGHT                 THEFT/OTHER
# 2    DAY                      THEFT/OTHER
#      EVENING                  THEFT/OTHER
#      MIDNIGHT                 THEFT/OTHER
# 3    DAY                      THEFT/OTHER
#      EVENING                  THEFT/OTHER
#      MIDNIGHT                 THEFT/OTHER
# 4    DAY                     THEFT F/AUTO
#      EVENING                  THEFT/OTHER
#      MIDNIGHT                 THEFT/OTHER
# 5    DAY                     THEFT F/AUTO
#      EVENING                  THEFT/OTHER
#      MIDNIGHT                 THEFT/OTHER
# 6    DAY                      THEFT/OTHER
#      EVENING                  THEFT/OTHER
#      MIDNIGHT                 THEFT/OTHER
# 7    DAY                     THEFT F/AUTO
#      EVENING                  THEFT/OTHER
#      MIDNIGHT                 THEFT/OTHER
# 8    DAY                     THEFT F/AUTO
#      EVENING                  THEFT/OTHER
#      MIDNIGHT  ASSAULT W/DANGEROUS WEAPON

# %% [markdown]
# ## Summarizing over all rows or all columns (without grouping)
#
# We can also use the `apply` function to summarize rows or columns efficiently

# %% [markdown]
# **Task**: find the mean lat and longitude in one line of code

# %%
df[["X","Y"]].mean()
# Out:
# X   -77.007049
# Y    38.907618
# dtype: float64

# %%
True == 1
# Out:
# True

# %%
aa = (df.X > -77)
aa.mean()
# Out:
# 0.41505853710930507

# %%
str.lower("I LOVE QSS20")
# Out:
# 'i love qss20'

# %%
"I LOVE QSS20".lower()
# Out:
# 'i love qss20'

# %%
df.SHIFT.str.lower()
# Out:
# 0        midnight
# 1         evening
# 2        midnight
# 3        midnight
# 4        midnight
#            ...
# 27926    midnight
# 27927         day
# 27928         day
# 27929     evening
# 27930     evening
# Name: SHIFT, Length: 27931, dtype: object

# %% [markdown]
# ## 2. Creating new columns/transforming their type

# %% [markdown]
# ### Simple filtering
#
# `np.where` is in the numpy package (aliased as `np`) and operates similar to `ifelse` in R
#
# But there is a built in pandas way to emulate this.
#
# **Task**: create an indicator `is_theft` for any offense that contains the word "THEFT"
#
# **Task**: create an indicator `is_theft_notmotor` for any offense that contains the word "THEFT" but does not contain the word "MOTOR"

# %%
np.where( df.OFFENSE.str.contains("THEFT"), True, False  )
# Out:
# array([False,  True, False, ...,  True,  True,  True])

# %% [markdown]
# ### np.select
#
# **Task**: create a new variable, `offense_summary`, where you:
#
# - Recode theft offenses that use a gun or knife as the method (`METHOD`) as: violent theft
# - Recode non-theft offenses that use a gun or knife as the method as: violent other
# - Recode all other as non-violent

# %%
# is_theft = df.OFFENSE.str.contains("THEFT")
# is_theft_notmotor = (is_theft) & (~(df.OFFENSE.str.contains("MOTOR")))
# print(df[is_theft_notmotor])

violent_theft = (df.METHOD.str.contains("GUN") | df.METHOD.str.contains("KNIFE")) & is_theft
violent_nontheft = (df.METHOD.str.contains("GUN") | df.METHOD.str.contains("KNIFE")) & ~(is_theft)
conditions = [violent_theft,violent_nontheft]
labels = ["Violent Theft", "Violent Non-Theft"]
df["offense_summary"] = np.select(conditions, labels, default="Non-violent")
#df.sort_values("offense_summary", ascending=False)

# %%
summaries = ['violent theft', 'violent other']
conditions = [
    df.METHOD.isin(['GUN', 'KNIFE']) & (df.is_theft),
    df.METHOD.isin(['GUN', 'KNIFE']) 
]
df['offense_summaries'] = np.select(conditions, summaries, default = 'non-violent')

# %%
df['offense_summaries'].value_counts()
# Out:
# offense_summaries
# non-violent      25256
# violent other     2640
# violent theft       35
# Name: count, dtype: int64

# %% [markdown]
# ### map.recode
#
# **Task**: recode shifts that are MIDNIGHT or EVENING as "nighttime"; code other shift to daytime

# %%
df.SHIFT.unique()
# Out:
# array(['MIDNIGHT', 'EVENING', 'DAY'], dtype=object)

# %%
# to see your vals in the SHIFT column:
map_from = ["MIDNIGHT", "EVENING", "DAY"]
map_to = ["nighttime", "nighttime", "daytime"]
conversion_dict = dict(zip(map_from, map_to))
df.SHIFT.map(conversion_dict)
# if u wanna actually recode your df column:
df["NEW_SHIFT"] = df.SHIFT.map(conversion_dict)
df.SHIFT
# Out:
# 0        nighttime
# 1        nighttime
# 2        nighttime
# 3        nighttime
# 4        nighttime
#            ...
# 27926    nighttime
# 27927      daytime
# 27928      daytime
# 27929    nighttime
# 27930    nighttime
# Name: SHIFT, Length: 27931, dtype: object
# 0        MIDNIGHT
# 1         EVENING
# 2        MIDNIGHT
# 3        MIDNIGHT
# 4        MIDNIGHT
#            ...
# 27926    MIDNIGHT
# 27927         DAY
# 27928         DAY
# 27929     EVENING
# 27930     EVENING
# Name: SHIFT, Length: 27931, dtype: object

# %%
conversion_dict.get("Collis", "oops")
# Out:
# 'oops'

# %%
df.SHIFT.apply(lambda x: conversion_dict[x] )
# Out:
# 0        nighttime
# 1        nighttime
# 2        nighttime
# 3        nighttime
# 4        nighttime
#            ...
# 27926    nighttime
# 27927      daytime
# 27928      daytime
# 27929    nighttime
# 27930    nighttime
# Name: SHIFT, Length: 27931, dtype: object

# %%
df.SHIFT = np.where(df["SHIFT"].str.contains("MIDNIGHT") |
                    df["SHIFT"].str.contains("EVENING"), 
                    "nighttime", "daytime")

# %%
df.SHIFT = np.where(   )
# Out:
# {'MIDNIGHT': 'nighttime', 'EVENING': 'nighttime', 'DAY': 'daytime'}

# %% [markdown]
# ### Using built-in pandas methods
#
# Another way of creating variables, used either alone or in combination with np.where and np.select is to use pandas built in `str` methods
#
# Basic structure is: `df['namestringcol'].str.someoperation`

# %% [markdown]
# **Task**: using a `str` method, create a new variable--`OFFENSE_NOSP`--that replaces spaces in the `OFFENSE` column with underscores

# %%
df["OFFENSE_NOSP"] = df["OFFENSE"].str.replace(" ","_")
df["OFFENSE_NOSP"]
# Out:
# 0                   HOMICIDE
# 1               THEFT_F/AUTO
# 2                   HOMICIDE
# 3                   HOMICIDE
# 4                   HOMICIDE
#                 ...
# 27926           THEFT_F/AUTO
# 27927           THEFT_F/AUTO
# 27928            THEFT/OTHER
# 27929    MOTOR_VEHICLE_THEFT
# 27930           THEFT_F/AUTO
# Name: OFFENSE_NOSP, Length: 27931, dtype: object

# %% [markdown]
# ### Transforming column types
#
# **Task**: check the type of the `START_DATE` column

# %%
# a.date = pd.to_datetime(a.date)
df.START_DATE.dtype
# Out:
# dtype('O')

# %%
df.START_DATE.iloc[0]
# Out:
# '2011/09/23 06:40:00+00'

# %% [markdown]
# **Task**: recast the `START_DATE` column to datetime, calling this `START_DATE_CLEAN`; coerce errors rather than cleaning the string; check the type of that new col

# %%
df["START_DATE_CLEAN"] = pd.to_datetime(df.START_DATE)

# %% [markdown]
# **Task:** print the min and max of `START_DATE_CLEAN`. What happens if you try to do this with `START_DATE`?

# %%
df.START_DATE_CLEAN.min(), df.START_DATE_CLEAN.max()
df.START_DATE.min(), df.START_DATE.max()
# Out:
# (Timestamp('1940-02-17 00:00:16+0000', tz='UTC'),
#  Timestamp('2021-01-01 02:30:21+0000', tz='UTC'))
# ('1940/02/17 00:00:16+00', '2021/01/01 02:30:21+00')

# %%
[ "2024/9/21", "2024/12/5" ]

# %%
"2024/09/21" < "2024/12/5"
# Out:
# True

# %% [markdown]
# ## 3. Row and column filtering

# %%
courses = ["QSS45", "QSS20", "CS01", "WRIT5"]

new_list = []
for c in courses:
    if "QSS" in c:
        new_list.append(c)
new_list
# Out:
# ['QSS45', 'QSS20']

# %%
new_list = [ c for c in courses if "QSS" in c  ]

# %%
num_list = [1,2,3,4,5]
[n+1 for n in num_list]
# Out:
# [2, 3, 4, 5, 6]

# %% [markdown]
# ### Row subsetting
#
# **Task**: filter to crime reports about theft using the `is_theft` definition and that are in ward 3

# %%
df[ df.is_theft & (df.WARD == 3) ]
# Out:
#                X          Y       CCN              REPORT_DAT     SHIFT  \
# 8     -77.078395  38.932427  20001484  2020/01/03 15:28:51+00       DAY
# 12    -77.063920  38.944876  20002785  2020/01/05 20:01:58+00   EVENING
# 13    -77.070772  38.956628  20003356  2020/01/07 01:11:27+00   EVENING
# 22    -77.085302  38.959915  20031068  2020/02/20 22:19:38+00   EVENING
# 39    -77.077697  38.937382  20111761  2020/08/05 18:08:56+00       DAY
# ...          ...        ...       ...                     ...       ...
# 27801 -77.070891  38.936810  20050233  2020/03/25 10:24:37+00  MIDNIGHT
# 27828 -77.058884  38.936195  20025378  2020/02/11 15:28:00+00       DAY
# 27907 -77.057640  38.924692  20153221  2020/10/26 13:15:04+00       DAY
# 27909 -77.063920  38.944876  20113247  2020/08/08 20:33:10+00   EVENING
# 27914 -77.058083  38.934832  20117502  2020/08/17 15:41:41+00       DAY
#
#        METHOD       OFFENSE                                         BLOCK  \
# 8      OTHERS  THEFT F/AUTO  3900 - 4099 BLOCK OF MASSACHUSETTS AVENUE NW
# 12     OTHERS   THEFT/OTHER    4200 - 4399 BLOCK OF CONNECTICUT AVENUE NW
# 13     OTHERS   THEFT/OTHER    5100 - 5199 BLOCK OF CONNECTICUT AVENUE NW
# 22     OTHERS   THEFT/OTHER      5300 - 5399 BLOCK OF WISCONSIN AVENUE NW
# 39     OTHERS  THEFT F/AUTO           3600 - 3699 BLOCK OF 39TH STREET NW
# ...       ...           ...                                           ...
# 27801  OTHERS   THEFT/OTHER           3500 - 3599 BLOCK OF 36TH STREET NW
# 27828  OTHERS   THEFT/OTHER    3500 - 3599 BLOCK OF CONNECTICUT AVENUE NW
# 27907  OTHERS   THEFT/OTHER           2700 - 2799 BLOCK OF 29TH STREET NW
# 27909  OTHERS   THEFT/OTHER    4200 - 4399 BLOCK OF CONNECTICUT AVENUE NW
# 27914  OTHERS   THEFT/OTHER    3319 - 3499 BLOCK OF CONNECTICUT AVENUE NW
#
#           XBLOCK     YBLOCK  ...  VOTING_PRECINCT   LATITUDE  LONGITUDE  BID  \
# 8      393203.00  140507.00  ...      Precinct 28  38.932419 -77.078393  NaN
# 12     394459.00  141888.00  ...      Precinct 34  38.944868 -77.063918  NaN
# 13     393866.00  143193.00  ...      Precinct 50  38.956620 -77.070770  NaN
# 22     392607.00  143559.00  ...      Precinct 32  38.959907 -77.085300  NaN
# 39     393264.00  141057.00  ...      Precinct 29  38.937374 -77.077695  NaN
# ...          ...        ...  ...              ...        ...        ...  ...
# 27801  393854.00  140993.00  ...      Precinct 27  38.936802 -77.070889  NaN
# 27828  394895.00  140924.00  ...      Precinct 34  38.936187 -77.058881  NaN
# 27907  395002.00  139647.00  ...      Precinct 26  38.924684 -77.057638  NaN
# 27909  394459.00  141888.00  ...      Precinct 34  38.944868 -77.063918  NaN
# 27914  394964.33  140772.69  ...      Precinct 34  38.934824 -77.058081  NaN
#
#                    START_DATE                END_DATE   OBJECTID  \
# 8      2020/01/02 23:33:38+00  2020/01/03 14:20:15+00  594453346
# 12     2020/01/05 19:40:52+00  2020/01/05 19:42:06+00  594453350
# 13     2020/01/06 20:28:26+00  2020/01/06 21:21:36+00  594453351
# 22     2020/02/20 21:05:43+00  2020/02/20 22:20:01+00  594453360
# 39     2020/08/05 17:21:04+00                     NaN  594453445
# ...                       ...                     ...        ...
# 27801  2020/03/24 15:56:42+00  2020/03/24 16:00:06+00  594980534
# 27828  2020/02/10 20:30:07+00  2020/02/11 02:30:26+00  594980726
# 27907  2020/10/24 17:00:36+00  2020/10/25 16:00:46+00  594980943
# 27909  2020/08/07 17:06:06+00  2020/08/07 17:16:08+00  594980968
# 27914  2020/08/17 15:16:33+00  2020/08/17 15:20:54+00  594980973
#
#       OCTO_RECORD_ID  is_theft  is_theft_notmotor
# 8                NaN      True               True
# 12               NaN      True               True
# 13               NaN      True               True
# 22               NaN      True               True
# 39               NaN      True               True
# ...              ...       ...                ...
# 27801            NaN      True               True
# 27828            NaN      True               True
# 27907            NaN      True               True
# 27909            NaN      True               True
# 27914            NaN      True               True
#
# [1522 rows x 27 columns]

# %% [markdown]
# ### Column subsetting

# %% [markdown]
# **Task**: select two columns--`START_DATE` and `END_DATE`--and print the head of the dataframe

# %%
df[ ["START_DATE", "END_DATE"] ].head()
# Out:
#                START_DATE                END_DATE
# 0  2011/09/23 06:40:00+00                     NaN
# 1  2020/01/11 02:48:51+00  2020/01/17 02:48:54+00
# 2  2010/09/02 04:00:00+00  2010/09/02 04:00:00+00
# 3  2010/10/10 02:00:00+00                     NaN
# 4  2018/03/26 08:40:06+00  2018/03/26 10:04:44+00

# %% [markdown]
# **Task**: use list comprehension to automate this a bit and select all columns with the word "DATE" in the name; print the head of the dataframe

# %%
df[ [ c for c in df.columns if "DATE" in c ] ]
# Out:
#                    START_DATE                END_DATE  \
# 0      2011/09/23 06:40:00+00                     NaN
# 1      2020/01/11 02:48:51+00  2020/01/17 02:48:54+00
# 2      2010/09/02 04:00:00+00  2010/09/02 04:00:00+00
# 3      2010/10/10 02:00:00+00                     NaN
# 4      2018/03/26 08:40:06+00  2018/03/26 10:04:44+00
# ...                       ...                     ...
# 27926  2020/10/17 07:20:23+00  2020/10/17 07:45:02+00
# 27927  2020/10/16 23:00:10+00  2020/10/16 23:05:17+00
# 27928  2020/10/18 16:30:23+00  2020/10/18 16:33:34+00
# 27929  2020/10/20 00:23:09+00  2020/10/20 00:24:57+00
# 27930  2020/10/16 21:00:03+00  2020/10/17 11:08:52+00
#
#                START_DATE_CLEAN
# 0     2011-09-23 06:40:00+00:00
# 1     2020-01-11 02:48:51+00:00
# 2     2010-09-02 04:00:00+00:00
# 3     2010-10-10 02:00:00+00:00
# 4     2018-03-26 08:40:06+00:00
# ...                         ...
# 27926 2020-10-17 07:20:23+00:00
# 27927 2020-10-16 23:00:10+00:00
# 27928 2020-10-18 16:30:23+00:00
# 27929 2020-10-20 00:23:09+00:00
# 27930 2020-10-16 21:00:03+00:00
#
# [27931 rows x 3 columns]

# %% [markdown]
# **Task**: filter reports of crime in `START_DATE_CLEAN` before May 2020 and that are located in ward 1; select the ward and `START_DATE` column and print a random sample of rows

# %%
df[ (df.START_DATE_CLEAN < "05-01-2020") & (df.WARD == 1) ][["WARD", "START_DATE"]]
# Out:
#        WARD              START_DATE
# 9         1  2020/01/03 04:20:19+00
# 16        1  2020/01/08 20:44:58+00
# 25        1  2020/02/21 17:15:39+00
# 60        1  2020/01/28 15:23:51+00
# 80        1  2020/02/18 23:09:54+00
# ...     ...                     ...
# 27322     1  2020/04/04 22:59:12+00
# 27325     1  2020/01/23 03:00:17+00
# 27716     1  2020/03/29 20:30:00+00
# 27733     1  2020/03/14 03:00:08+00
# 27746     1  2020/03/08 02:50:50+00
#
# [1148 rows x 2 columns]

# %%
df.shape
# Out:
# (27931, 28)
