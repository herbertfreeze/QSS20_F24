# %%
## imports
import pandas as pd
import numpy as np
import re
import requests
import yaml


## repeated printouts
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # 1. Example 1: no credentials; no wrapper
#
# Site: National Assessment of Education Progress (NAEP)
#
# Documentation: https://www.nationsreportcard.gov/api_documentation.aspx
#
# Base link: https://www.nationsreportcard.gov/DataService/GetAdhocData.aspx

# %% [markdown]
# ## 1.1 Query to pull some data

# %%
## using their example query of 2011 writing scores separated by gender
## based on here - https://stackoverflow.com/questions/40836749/pythonic-way-of-writing-a-single-line-long-string
## using the ( ) syntax to formulate a long
## string without linebreaks added
example_naep_query = (
'https://www.nationsreportcard.gov/'
'Dataservice/GetAdhocData.aspx?'
'type=data&subject=writing&grade=8&'
'subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2011')


example_naep_query
# Out:
# 'https://www.nationsreportcard.gov/Dataservice/GetAdhocData.aspx?type=data&subject=writing&grade=8&subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2011'

# %%
## use requests to call the api
naep_resp = requests.get(example_naep_query)
naep_resp
print(type(naep_resp))

## get the json contents of the response 
## here, we're assuming valid response
naep_resp_j = naep_resp.json()
naep_resp_j

## with result, turn it into a dataframe
naep_resp_d = pd.DataFrame(naep_resp_j['result'])
naep_resp_d
# Out:
# <Response [200]>
# <class 'requests.models.Response'>
# {'status': 200,
#  'result': [{'year': 2011,
#    'sample': 'R3',
#    'yearSampleLabel': '2011',
#    'Cohort': 2,
#    'CohortLabel': 'Grade 8',
#    'stattype': 'MN:MN',
#    'subject': 'WRI',
#    'grade': 8,
#    'scale': 'WRIRP',
#    'jurisdiction': 'NP',
#    'jurisLabel': 'National public',
#    'variable': 'GENDER',
#    'variableLabel': 'Gender',
#    'varValue': '1',
#    'varValueLabel': 'Male',
#    'value': 139.099504632971,
#    'isStatDisplayable': 1,
#    'errorFlag': 0},
#   {'year': 2011,
#    'sample': 'R3',
#    'yearSampleLabel': '2011',
#    'Cohort': 2,
#    'CohortLabel': 'Grade 8',
#    'stattype': 'MN:MN',
#    'subject': 'WRI',
#    'grade': 8,
#    'scale': 'WRIRP',
#    'jurisdiction': 'NP',
#    'jurisLabel': 'National public',
#    'variable': 'GENDER',
#    'variableLabel': 'Gender',
#    'varValue': '2',
#    'varValueLabel': 'Female',
#    'value': 158.567104984955,
#    'isStatDisplayable': 1,
#    'errorFlag': 0}]}
#    year sample yearSampleLabel  Cohort CohortLabel stattype subject  grade  \
# 0  2011     R3            2011       2     Grade 8    MN:MN     WRI      8
# 1  2011     R3            2011       2     Grade 8    MN:MN     WRI      8
#
#    scale jurisdiction       jurisLabel variable variableLabel varValue  \
# 0  WRIRP           NP  National public   GENDER        Gender        1
# 1  WRIRP           NP  National public   GENDER        Gender        2
#
#   varValueLabel       value  isStatDisplayable  errorFlag
# 0          Male  139.099505                  1          0
# 1        Female  158.567105                  1          0

# %% [markdown]
# ## 1.2 What happens if there's an error in our query?

# %%
## here's a query that from the documentation we know
## won't work since i modified year to 2025 which doesnt
## exist in the data
wrong_naep_query = (
'https://www.nationsreportcard.gov/'
'Dataservice/GetAdhocData.aspx?'
'type=data&subject=writing&grade=8&'
'subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2028')

wrong_naep_query
# Out:
# 'https://www.nationsreportcard.gov/Dataservice/GetAdhocData.aspx?type=data&subject=writing&grade=8&subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2028'

# %%
## use requests to call the api
naep_wrong_resp = requests.get(wrong_naep_query)
naep_wrong_resp
# Out:
# <Response [200]>

# %%
## in the case of this particular api,
## the call returns some response but
## when we try to extract the json containing
## status or results, we get in an error
#naep_wrong_resp.json() # uncomment to see error

# %% [markdown]
# ### 1.2.2 More all-purpose way of allowing remainder of calls to run: try, except

# %%
## putting it in a try; except as general error catching
try:
    results = naep_wrong_resp.json()['result']
except Exception as e:
    print('Failed to get result from API due to error:')
    print(e) # or just: pass
# Out:
# Failed to get result from API due to error:
# Invalid control character at: line 1 column 289 (char 288)

# %% [markdown]
# ### 1.2.3 Can usually also find more targeted way but that varies more across APIs

# %%
## if we wanted do more specific error catching,
## see that the status == 400 actually appears here
## so could write if else along those lines
naep_wrong_resp.text
naep_resp.text

if "System.Exception" in naep_wrong_resp.text:
    print("NAEP results not found")
# Out:
# '{"status":400,"result": "System.Exception: The query \'SELECT DISTINCT Framework FROM Cycles WHERE Subject=\'WRI\' AND Cohort=2 AND CONVERT(VARCHAR(10),Year)+Sample IN (\'2028R3\')\' did not return exactly 1 framework. Make sure you can trend the years defined for the given subject and cohort.\r\n   at NRCDataService3.GetAdhocData.GetFramework(NDEContext& ndeContext, String subjectCode, List`1 yearSamples, String cohort) in C:\\projects\\ndecore2015\\NRCDataService2\\GetAdhocData.aspx.cs:line 2380\r\n   at NRCDataService3.GetAdhocData.PopulateBaseOrchestratorRequest() in C:\\projects\\ndecore2015\\NRCDataService2\\GetAdhocData.aspx.cs:line 2010\r\n   at NRCDataService3.GetAdhocData.ConstructRequest_Datapoint() in C:\\projects\\ndecore2015\\NRCDataService2\\GetAdhocData.aspx.cs:line 651\r\n   at NRCDataService3.GetAdhocData.Page_Load(Object sender, EventArgs e) in C:\\projects\\ndecore2015\\NRCDataService2\\GetAdhocData.aspx.cs:line 191"}'
# '{"status":200,"result": [{"year":2011,"sample":"R3","yearSampleLabel":"2011","Cohort":2,"CohortLabel":"Grade 8","stattype":"MN:MN","subject":"WRI","grade":8,"scale":"WRIRP","jurisdiction":"NP","jurisLabel":"National public","variable":"GENDER","variableLabel":"Gender","varValue":"1","varValueLabel":"Male","value":139.099504632971,"isStatDisplayable":1,"errorFlag":0},{"year":2011,"sample":"R3","yearSampleLabel":"2011","Cohort":2,"CohortLabel":"Grade 8","stattype":"MN:MN","subject":"WRI","grade":8,"scale":"WRIRP","jurisdiction":"NP","jurisLabel":"National public","variable":"GENDER","variableLabel":"Gender","varValue":"2","varValueLabel":"Female","value":158.567104984955,"isStatDisplayable":1,"errorFlag":0}]}'
# NAEP results not found

# %% [markdown]
# ## Activity 1: writing a function to make multiple, sequential calls
#
# - Say we want to pull the data for grades 4, 8, and 12
# - How can we write a function that iterates over a list of those grades and pulls the data for each grade?
#
# **Note**: an ideal function would have arguments for each parameter in the API like subject, subscale, etc. Here we can leave those other parts constant

# %%
def pull_data(grades):

    # data = pd.DataFrame()
    data = []
    
    for grade in grades:
        
        naep_query = (
    'https://www.nationsreportcard.gov/'
    'Dataservice/GetAdhocData.aspx?'
    'type=data&subject=writing&grade={}&'
    'subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2011').format(grade) # automatically inserts grade into {}

        naep_resp = requests.get(naep_query)

        try:
            naep_resp_j = naep_resp.json()['result']
            naep_resp_d = pd.DataFrame(naep_resp_j)
            # data = pd.concat([data,naep_resp_d])
            data.append(naep_resp_d)
        except Exception as e: 
            print('Failed to get result from API due to error:')
            print(e)
        
    return pd.concat(data)

pull_data([4,7,8,12])
# Out:
# Failed to get result from API due to error:
# Invalid control character at: line 1 column 289 (char 288)
# Failed to get result from API due to error:
# DataFrame constructor not properly called!
#    year sample yearSampleLabel  Cohort CohortLabel stattype subject  grade  \
# 0  2011     R3            2011       2     Grade 8    MN:MN     WRI      8
# 1  2011     R3            2011       2     Grade 8    MN:MN     WRI      8
# 0  2011     R3            2011       3    Grade 12    MN:MN     WRI     12
# 1  2011     R3            2011       3    Grade 12    MN:MN     WRI     12
#
#    scale jurisdiction       jurisLabel variable variableLabel varValue  \
# 0  WRIRP           NP  National public   GENDER        Gender        1
# 1  WRIRP           NP  National public   GENDER        Gender        2
# 0  WRIRP           NP  National public   GENDER        Gender        1
# 1  WRIRP           NP  National public   GENDER        Gender        2
#
#   varValueLabel       value  isStatDisplayable  errorFlag
# 0          Male  139.099505                  1          0
# 1        Female  158.567105                  1          0
# 0          Male  141.256978                  1          0
# 1        Female  155.385917                  1          0

# %% [markdown]
# # 2. Example 2: needs credentials; no wrapper

# %% [markdown]
# Create an account here: https://www.yelp.com/developers/v3/manage_app

# %%
## get the key
API_KEY = "PofPfLz8nkwXfSTn8f4y9DxxRhiKNUcj2g4TujHc6nyAymaqTfTimMzOO-Ry_fwVncMvW7lB7WsH6dp9ULVOWoRbDeii-bn1brUyk7Rz03eJhXoalT4nVU9LqWUaZ3Yx"

# %%
## use documentation to define what to search
## doc: https://www.yelp.com/developers/documentation/v3/business_search
## write the query 
base_url = "https://api.yelp.com/v3/businesses/search?"
my_name = "restaurants"
my_location = "Hanover,NH,03755"
yelp_genquery = ('{base_url}'
                'term={name}'
                '&location={loc}').format(base_url = base_url,
                name = my_name,
                loc = my_location)

## use requests to call the API; here, we're
## passing it our credentials (structure varies
## by API and telling it to only return 10 results
## (max is 50 at once)
header = {'Authorization': f"Bearer {API_KEY}"}
yelp_genresp = requests.get(yelp_genquery, headers = header)
yelp_genresp

## then, look at structure of response
yelp_genjson = yelp_genresp.json()
yelp_genjson
# Out:
# <Response [200]>
# {'businesses': [{'id': 'XVGEEIH5rVB2QzW-qywcJw',
#    'alias': 'base-camp-cafe-hanover',
#    'name': 'Base Camp Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/p8_YiEQI7p_JF82eaWa9Xg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/base-camp-cafe-hanover?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 252,
#    'categories': [{'alias': 'himalayan', 'title': 'Himalayan/Nepalese'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 43.700626, 'longitude': -72.2887803},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '3 Lebanon St',
#     'address2': 'Ste 13',
#     'address3': '',
#     'city': 'Hanover',
#     'zip_code': '03755',
#     'country': 'US',
#     'state': 'NH',
#     'display_address': ['3 Lebanon St', 'Ste 13', 'Hanover, NH 03755']},
#    'phone': '+16036432007',
#    'display_phone': '(603) 643-2007',
#    'distance': 196.1397581876442,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1100',
#        'end': '2100',
#        'day': 1},
#       {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 2},
#       {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 3},
#       {'is_overnight': False, 'start': '1100', 'end': '2130', 'day': 4},
#       {'is_overnight': False, 'start': '1100', 'end': '2130', 'day': 5},
#       {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://basecampcafenewhampshire.com/menu/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '8ybF6YyRldtZmU9jil4xlg',
#    'alias': 'mollys-restaurant-and-bar-hanover',
#    'name': "Molly's Restaurant & Bar",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TJLrrA6z-SnPgZfrs2GQNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mollys-restaurant-and-bar-hanover?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 545,
#    'categories': [{'alias': 'tradamerican', 'title': 'American'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.9,
#    'coordinates': {'latitude': 43.701144, 'longitude': -72.2894249},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '43 South Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Hanover',
#     'zip_code': '03755',
#     'country': 'US',
#     'state': 'NH',
#     'display_address': ['43 South Main St', 'Hanover, NH 03755']},
#    'phone': '+16036432570',
#    'display_phone': '(603) 643-2570',
#    'distance': 250.8301601841674,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1130',
#        'end': '2200',
#        'day': 0},
#       {'is_overnight': False, 'start': '1130', 'end': '2200', 'day': 1},
#       {'is_overnight': False, 'start': '1130', 'end': '2200', 'day': 2},
#       {'is_overnight': False, 'start': '1130', 'end': '2200', 'day': 3},
#       {'is_overnight': False, 'start': '1130', 'end': '0000', 'day': 4},
#       {'is_overnight': False, 'start': '1130', 'end': '0000', 'day': 5},
#       {'is_overnight': False, 'start': '1130', 'end': '2200', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.mollysrestaurant.com/uploadcache/Mollys-Menu.pdf',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'qxm3VNmD0O2zw8m9U8SxZg',
#    'alias': 'duende-hanover-2',
#    'name': 'Duende',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rf_h2DP7M3BtubbWHprQDg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/duende-hanover-2?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 15,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.7,
#    'coordinates': {'latitude': 43.70074272457673,
#     'longitude': -72.2876837477088},
#    'transactions': [],
#    'location': {'address1': '15 Lebanon St',
#     'address2': '',
#     'address3': None,
#     'city': 'Hanover',
#     'zip_code': '03755',
#     'country': 'US',
#     'state': 'NH',
#     'display_address': ['15 Lebanon St', 'Hanover, NH 03755']},
#    'phone': '+16033064826',
#    'display_phone': '(603) 306-4826',
#    'distance': 107.38886229011861,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1200',
#        'end': '2100',
#        'day': 2},
#       {'is_overnight': False, 'start': '1200', 'end': '2100', 'day': 3},
#       {'is_overnight': False, 'start': '1200', 'end': '2100', 'day': 4},
#       {'is_overnight': False, 'start': '1200', 'end': '2100', 'day': 5},
#       {'is_overnight': False, 'start': '1200', 'end': '2100', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'https://www.esduende.com/_files/ugd/412142_74b0661f85294561b61ebe6f4e8b503b.pdf',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '5WW4g_LRwau29KyjZGLyAA',
#    'alias': 'sawtooth-kitchen-hanover',
#    'name': 'Sawtooth Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/61MNG4d1fmE2TW1Ie_b01w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sawtooth-kitchen-hanover?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 29,
#    'categories': [{'alias': 'chickenshop', 'title': 'Chicken Shop'}],
#    'rating': 4.1,
#    'coordinates': {'latitude': 43.70158, 'longitude': -72.289641},
#    'transactions': [],
#    'location': {'address1': '33 S Main St',
#     'address2': '',
#     'address3': None,
#     'city': 'Hanover',
#     'zip_code': '03755',
#     'country': 'US',
#     'state': 'NH',
#     'display_address': ['33 S Main St', 'Hanover, NH 03755']},
#    'phone': '+16036435134',
#    'display_phone': '(603) 643-5134',
#    'distance': 242.6075518026577,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1600',
#        'end': '2100',
#        'day': 0},
#       {'is_overnight': False, 'start': '1100', 'end': '2300', 'day': 1},
#       {'is_overnight': False, 'start': '1100', 'end': '2300', 'day': 2},
#       {'is_overnight': False, 'start': '1100', 'end': '0000', 'day': 3},
#       {'is_overnight': True, 'start': '1100', 'end': '0100', 'day': 4},
#       {'is_overnight': True, 'start': '1100', 'end': '0100', 'day': 5}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'https://www.sawtoothkitchen.com/menus',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'wyV_NfYn4ZOfp_sHMDPcAw',
#    'alias': 'bistro-at-six-hanover',
#    'name': 'Bistro at Six',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/i4jvssUsxa79VYVLOD3TmQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bistro-at-six-hanover?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 2,
#    'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tradamerican', 'title': 'American'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 43.7001146, 'longitude': -72.2877078},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '6 E South St',
#     'address2': None,
#     'address3': '',
#     'city': 'Hanover',
#     'zip_code': '03755',
#     'country': 'US',
#     'state': 'NH',
#     'display_address': ['6 E South St', 'Hanover, NH 03755']},
#    'phone': '+16036430600',
#    'display_phone': '(603) 643-0600',
#    'distance': 198.65178837196856,
#    'business_hours': [{'open': [{'is_overnight': True,
#        'start': '0000',
#        'end': '0000',
#        'day': 0},
#       {'is_overnight': True, 'start': '0000', 'end': '0000', 'day': 1},
#       {'is_overnight': True, 'start': '0000', 'end': '0000', 'day': 2},
#       {'is_overnight': True, 'start': '0000', 'end': '0000', 'day': 3},
#       {'is_overnight': True, 'start': '0000', 'end': '0000', 'day': 4},
#       {'is_overnight': True, 'start': '0000', 'end': '0000', 'day': 5},
#       {'is_overnight': True, 'start': '0000', 'end': '0000', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'KA8yhrd-ClVYMyOefXdVYg',
#    'alias': 'lous-restaurant-and-bakery-hanover',
#    'name': "Lou's Restaurant & Bakery",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/VAx8H9Xy_Dc_mAY-nuNt9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lous-restaurant-and-bakery-hanover?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 408,
#    'categories': [{'alias': 'tradamerican', 'title': 'American'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 43.70143, 'longitude': -72.289001},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '30 S Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Hanover',
#     'zip_code': '03755',
#     'country': 'US',
#     'state': 'NH',
#     'display_address': ['30 S Main St', 'Hanover, NH 03755']},
#    'phone': '+16036433321',
#    'display_phone': '(603) 643-3321',
#    'distance': 244.00605927937792,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '0630',
#        'end': '1500',
#        'day': 0},
#       {'is_overnight': False, 'start': '0630', 'end': '1500', 'day': 1},
#       {'is_overnight': False, 'start': '0630', 'end': '1500', 'day': 2},
#       {'is_overnight': False, 'start': '0630', 'end': '1500', 'day': 3},
#       {'is_overnight': False, 'start': '0630', 'end': '1500', 'day': 4},
#       {'is_overnight': False, 'start': '0630', 'end': '1500', 'day': 5},
#       {'is_overnight': False, 'start': '0630', 'end': '1500', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'https://lousrestaurant.com/pages/menu',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '34j_2nRCVQBTKafJvncZlg',
#    'alias': 'pine-restaurant-hanover-2',
#    'name': 'PINE Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/c2SgURpO89OGUXP3r_sM8w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pine-restaurant-hanover-2?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 237,
#    'categories': [{'alias': 'newamerican', 'title': 'New American'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.7024572, 'longitude': -72.2875656},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '2 E Wheelock St',
#     'address2': None,
#     'address3': '',
#     'city': 'Hanover',
#     'zip_code': '03755',
#     'country': 'US',
#     'state': 'NH',
#     'display_address': ['2 E Wheelock St', 'Hanover, NH 03755']},
#    'phone': '+16036468000',
#    'display_phone': '(603) 646-8000',
#    'distance': 256.00429144986015,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '0700',
#        'end': '1045',
#        'day': 0},
#       {'is_overnight': False, 'start': '1130', 'end': '2200', 'day': 0},
#       {'is_overnight': False, 'start': '0700', 'end': '1045', 'day': 1},
#       {'is_overnight': False, 'start': '1130', 'end': '2200', 'day': 1},
#       {'is_overnight': False, 'start': '0700', 'end': '1045', 'day': 2},
#       {'is_overnight': False, 'start': '1130', 'end': '2200', 'day': 2},
#       {'is_overnight': False, 'start': '0700', 'end': '1045', 'day': 3},
#       {'is_overnight': False, 'start': '1130', 'end': '2200', 'day': 3},
#       {'is_overnight': False, 'start': '0700', 'end': '1045', 'day': 4},
#       {'is_overnight': False, 'start': '1130', 'end': '2200', 'day': 4},
#       {'is_overnight': False, 'start': '0700', 'end': '1045', 'day': 5},
#       {'is_overnight': False, 'start': '1130', 'end': '2200', 'day': 5},
#       {'is_overnight': False, 'start': '0700', 'end': '1045', 'day': 6},
#       {'is_overnight': False, 'start': '1130', 'end': '2200', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'https://www.pineathanoverinn.com/menu',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'jAFLKiVXq9z_h4ZPy0nLMA',
#    'alias': 'the-works-café-hanover',
#    'name': 'The Works Bakery Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/olpsy-B-taHe8lT6YYDViQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-works-caf%C3%A9-hanover?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 23,
#    'categories': [{'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 43.701789, 'longitude': -72.289672},
#    'transactions': [],
#    'location': {'address1': '25 S Main St',
#     'address2': '',
#     'address3': None,
#     'city': 'Hanover',
#     'zip_code': '03755',
#     'country': 'US',
#     'state': 'NH',
#     'display_address': ['25 S Main St', 'Hanover, NH 03755']},
#    'phone': '+18774192113',
#    'display_phone': '(877) 419-2113',
#    'distance': 293.8675321816416,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '0600',
#        'end': '2000',
#        'day': 0},
#       {'is_overnight': False, 'start': '0600', 'end': '2000', 'day': 1},
#       {'is_overnight': False, 'start': '0600', 'end': '2000', 'day': 2},
#       {'is_overnight': False, 'start': '0600', 'end': '2000', 'day': 3},
#       {'is_overnight': False, 'start': '0600', 'end': '2000', 'day': 4},
#       {'is_overnight': False, 'start': '0600', 'end': '2000', 'day': 5},
#       {'is_overnight': False, 'start': '0600', 'end': '2000', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'eba9e8OxN7pAhxoDT-J0ww',
#    'alias': 'the-nest-kitchen-hanover',
#    'name': 'The Nest Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3Ume3C8ImR817N_OL9QgcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-nest-kitchen-hanover?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 24,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 3.8,
#    'coordinates': {'latitude': 43.70059612109659,
#     'longitude': -72.28988918523648},
#    'transactions': [],
#    'location': {'address1': '57 S Main St',
#     'address2': None,
#     'address3': '',
#     'city': 'Hanover',
#     'zip_code': '03755',
#     'country': 'US',
#     'state': 'NH',
#     'display_address': ['57 S Main St', 'Hanover, NH 03755']},
#    'phone': '+16032772916',
#    'display_phone': '(603) 277-2916',
#    'distance': 285.28661217098033,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '0800',
#        'end': '1500',
#        'day': 1},
#       {'is_overnight': False, 'start': '0800', 'end': '1500', 'day': 2},
#       {'is_overnight': False, 'start': '0800', 'end': '1500', 'day': 3},
#       {'is_overnight': False, 'start': '0800', 'end': '1500', 'day': 4},
#       {'is_overnight': False, 'start': '0800', 'end': '1500', 'day': 5},
#       {'is_overnight': False, 'start': '0800', 'end': '1500', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'https://thenestkitchen.com/breakfast-menu/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'neBEWvgHNhsXIBImCYx_6A',
#    'alias': 'murphy-s-on-the-green-hanover',
#    'name': 'Murphy’s on the Green',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/76DCQrgDN8Nqe3QKDA-opw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/murphy-s-on-the-green-hanover?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 185,
#    'categories': [{'alias': 'newamerican', 'title': 'New American'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'pubs', 'title': 'Pubs'}],
#    'rating': 3.8,
#    'coordinates': {'latitude': 43.702, 'longitude': -72.2894949},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '11 S Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Hanover',
#     'zip_code': '03755',
#     'country': 'US',
#     'state': 'NH',
#     'display_address': ['11 S Main St', 'Hanover, NH 03755']},
#    'phone': '+16036434075',
#    'display_phone': '(603) 643-4075',
#    'distance': 295.20752311926014,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1600',
#        'end': '2330',
#        'day': 0},
#       {'is_overnight': False, 'start': '1600', 'end': '2330', 'day': 1},
#       {'is_overnight': False, 'start': '1600', 'end': '2330', 'day': 2},
#       {'is_overnight': False, 'start': '1600', 'end': '2330', 'day': 3},
#       {'is_overnight': False, 'start': '1200', 'end': '0000', 'day': 4},
#       {'is_overnight': False, 'start': '1200', 'end': '0000', 'day': 5},
#       {'is_overnight': False, 'start': '1200', 'end': '2330', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'vMyN7JL5cJExJORgIobbQg',
#    'alias': 'tuk-tuk-thai-cuisine-hanover',
#    'name': 'Tuk Tuk Thai Cuisine',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/--bUG38dWvNQ0V3f6e9iEQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tuk-tuk-thai-cuisine-hanover?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 319,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 43.70202, 'longitude': -72.28953},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '5 S Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Hanover',
#     'zip_code': '03755',
#     'country': 'US',
#     'state': 'NH',
#     'display_address': ['5 S Main St', 'Hanover, NH 03755']},
#    'phone': '+16032779192',
#    'display_phone': '(603) 277-9192',
#    'distance': 301.2194017699603,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1100',
#        'end': '2130',
#        'day': 0},
#       {'is_overnight': False, 'start': '1100', 'end': '2130', 'day': 1},
#       {'is_overnight': False, 'start': '1100', 'end': '2130', 'day': 2},
#       {'is_overnight': False, 'start': '1100', 'end': '2130', 'day': 3},
#       {'is_overnight': False, 'start': '1100', 'end': '2130', 'day': 4},
#       {'is_overnight': False, 'start': '1100', 'end': '2130', 'day': 5},
#       {'is_overnight': False, 'start': '1130', 'end': '2100', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.tuktukthaicuisine.com/index.php/tuk-tuk-menu',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'Tg8O0iPqeD_IjFGwTLqacw',
#    'alias': 'han-fusion-hanover',
#    'name': 'Han Fusion',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/CvUlbJi7Hb03cQCJErPf-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/han-fusion-hanover?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 57,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 43.700641, 'longitude': -72.2887803},
#    'transactions': ['delivery'],
#    'location': {'address1': '3 Lebanon St',
#     'address2': 'Ste 15',
#     'address3': None,
#     'city': 'Hanover',
#     'zip_code': '03755',
#     'country': 'US',
#     'state': 'NH',
#     'display_address': ['3 Lebanon St', 'Ste 15', 'Hanover, NH 03755']},
#    'phone': '+16036438888',
#    'display_phone': '(603) 643-8888',
#    'distance': 196.01251786876801,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1130',
#        'end': '2100',
#        'day': 1},
#       {'is_overnight': False, 'start': '1130', 'end': '2100', 'day': 2},
#       {'is_overnight': False, 'start': '1130', 'end': '2100', 'day': 3},
#       {'is_overnight': False, 'start': '1130', 'end': '2130', 'day': 4},
#       {'is_overnight': False, 'start': '1130', 'end': '2130', 'day': 5},
#       {'is_overnight': False, 'start': '1200', 'end': '2100', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'GXX6xbCK1EBH9X6zJf3wVA',
#    'alias': 'sushiya-hanover-2',
#    'name': 'Sushiya',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/v5MFXBIPHKyHovFE2X4Jjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushiya-hanover-2?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 102,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 43.699737, 'longitude': -72.289326},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '72 S Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Hanover',
#     'zip_code': '03755',
#     'country': 'US',
#     'state': 'NH',
#     'display_address': ['72 S Main St', 'Hanover, NH 03755']},
#    'phone': '+16036434000',
#    'display_phone': '(603) 643-4000',
#    'distance': 265.40959563254313,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1100',
#        'end': '2100',
#        'day': 0},
#       {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 1},
#       {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 2},
#       {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 3},
#       {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 4},
#       {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 5},
#       {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.hanoversushiya.com/#menu',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'Ecdu5qYM09F647Uoez99vg',
#    'alias': 'ramuntos-brick-and-brew-pizzeria-hanover',
#    'name': "Ramunto's Brick & Brew Pizzeria",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bPy9NZGEsPsmi8dtCzI77w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ramuntos-brick-and-brew-pizzeria-hanover?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 146,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 3.6,
#    'coordinates': {'latitude': 43.6998454, 'longitude': -72.2877323},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '9 E South St',
#     'address2': '',
#     'address3': '',
#     'city': 'Hanover',
#     'zip_code': '03755',
#     'country': 'US',
#     'state': 'NH',
#     'display_address': ['9 E South St', 'Hanover, NH 03755']},
#    'phone': '+16036439500',
#    'display_phone': '(603) 643-9500',
#    'distance': 160.30455594506685,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1100',
#        'end': '2100',
#        'day': 0},
#       {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 1},
#       {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 2},
#       {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 3},
#       {'is_overnight': False, 'start': '1100', 'end': '2200', 'day': 4},
#       {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 5},
#       {'is_overnight': False, 'start': '1200', 'end': '2100', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://ramuntospizza.com/menu/wood-fire-pizza/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'uZ6rg3gYgoWqFB5tOB49VQ',
#    'alias': 'tacos-y-tequila-hanover',
#    'name': 'Tacos Y Tequila',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2tr2DorwXG0scfVi79Rz-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tacos-y-tequila-hanover?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 32,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 3.2,
#    'coordinates': {'latitude': 43.70063761388881, 'longitude': -72.2887803},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3 Lebanon St',
#     'address2': '',
#     'address3': None,
#     'city': 'Hanover',
#     'zip_code': '03755',
#     'country': 'US',
#     'state': 'NH',
#     'display_address': ['3 Lebanon St', 'Hanover, NH 03755']},
#    'phone': '+16036963155',
#    'display_phone': '(603) 696-3155',
#    'distance': 196.04000826741668,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1100',
#        'end': '2200',
#        'day': 0},
#       {'is_overnight': False, 'start': '1100', 'end': '2200', 'day': 1},
#       {'is_overnight': False, 'start': '1100', 'end': '2200', 'day': 2},
#       {'is_overnight': False, 'start': '1100', 'end': '2200', 'day': 3},
#       {'is_overnight': False, 'start': '1100', 'end': '2300', 'day': 4},
#       {'is_overnight': False, 'start': '1100', 'end': '2300', 'day': 5},
#       {'is_overnight': False, 'start': '1000', 'end': '1400', 'day': 6},
#       {'is_overnight': False, 'start': '1500', 'end': '2100', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'https://www.tacosytequilahanover.com/menu',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'YJ3XYASE8ML-Tb18Q7Qfyg',
#    'alias': 'boloco-hanover-6',
#    'name': 'Boloco',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Jf7PzeOU8j955uazxuIJwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boloco-hanover-6?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 134,
#    'categories': [{'alias': 'newamerican', 'title': 'New American'}],
#    'rating': 3.7,
#    'coordinates': {'latitude': 43.7013062264829,
#     'longitude': -72.2895859997003},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '35 S Main St',
#     'address2': '',
#     'address3': 'Dartmouth College',
#     'city': 'Hanover',
#     'zip_code': '03755',
#     'country': 'US',
#     'state': 'NH',
#     'display_address': ['35 S Main St',
#      'Dartmouth College',
#      'Hanover, NH 03755']},
#    'phone': '+16036430202',
#    'display_phone': '(603) 643-0202',
#    'distance': 267.06370075516855,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1100',
#        'end': '2100',
#        'day': 0},
#       {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 1},
#       {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 2},
#       {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 3},
#       {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 4},
#       {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 5},
#       {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': '',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'VmMQltoybbk2XFQlWXktLw',
#    'alias': 'jewel-of-india-restaurant-hanover',
#    'name': 'Jewel of India Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xhyLnDNqDa2-J9EooMhyuw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jewel-of-india-restaurant-hanover?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 165,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 3.2,
#    'coordinates': {'latitude': 43.700907, 'longitude': -72.286006},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '11 Lebanon St',
#     'address2': '',
#     'address3': '',
#     'city': 'Hanover',
#     'zip_code': '03755',
#     'country': 'US',
#     'state': 'NH',
#     'display_address': ['11 Lebanon St', 'Hanover, NH 03755']},
#    'phone': '+16036432217',
#    'display_phone': '(603) 643-2217',
#    'distance': 31.564101493166955,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1130',
#        'end': '1430',
#        'day': 0},
#       {'is_overnight': False, 'start': '1630', 'end': '2200', 'day': 0},
#       {'is_overnight': False, 'start': '1130', 'end': '1430', 'day': 1},
#       {'is_overnight': False, 'start': '1630', 'end': '2200', 'day': 1},
#       {'is_overnight': False, 'start': '1130', 'end': '1430', 'day': 2},
#       {'is_overnight': False, 'start': '1630', 'end': '2200', 'day': 2},
#       {'is_overnight': False, 'start': '1130', 'end': '1430', 'day': 3},
#       {'is_overnight': False, 'start': '1630', 'end': '2200', 'day': 3},
#       {'is_overnight': False, 'start': '1130', 'end': '1430', 'day': 4},
#       {'is_overnight': False, 'start': '1630', 'end': '2200', 'day': 4},
#       {'is_overnight': False, 'start': '1130', 'end': '1430', 'day': 5},
#       {'is_overnight': False, 'start': '1630', 'end': '2200', 'day': 5},
#       {'is_overnight': False, 'start': '1130', 'end': '1430', 'day': 6},
#       {'is_overnight': False, 'start': '1630', 'end': '2200', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://jewelofindiahanover.com/menu.html',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '1yTM59uje_iMMdwKXI7-sA',
#    'alias': 'umplebys-bakery-and-cafe-hanover',
#    'name': "Umpleby's Bakery & Cafe",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jlAlp5GmOrf1YvueIm6HeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/umplebys-bakery-and-cafe-hanover?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 83,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'customcakes', 'title': 'Custom Cakes'}],
#    'rating': 3.1,
#    'coordinates': {'latitude': 43.69993, 'longitude': -72.288839},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '3 South St',
#     'address2': '',
#     'address3': '',
#     'city': 'Hanover',
#     'zip_code': '03755',
#     'country': 'US',
#     'state': 'NH',
#     'display_address': ['3 South St', 'Hanover, NH 03755']},
#    'phone': '+16036433030',
#    'display_phone': '(603) 643-3030',
#    'distance': 220.8437964167156,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '0800',
#        'end': '1500',
#        'day': 0},
#       {'is_overnight': False, 'start': '0800', 'end': '1500', 'day': 1},
#       {'is_overnight': False, 'start': '0800', 'end': '1500', 'day': 2},
#       {'is_overnight': False, 'start': '0800', 'end': '1500', 'day': 3},
#       {'is_overnight': False, 'start': '0800', 'end': '1500', 'day': 4},
#       {'is_overnight': False, 'start': '0800', 'end': '1500', 'day': 5},
#       {'is_overnight': False, 'start': '0800', 'end': '1500', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'EAE-lFuMDeDIIlDtVba79w',
#    'alias': 'dunks-hanover',
#    'name': 'Dunks',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RYe7AKZFGba46UQ3sisQog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dunks-hanover?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 9,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'newamerican', 'title': 'New American'}],
#    'rating': 3.2,
#    'coordinates': {'latitude': 43.70072, 'longitude': -72.28945},
#    'transactions': [],
#    'location': {'address1': '7 Lebanon St',
#     'address2': '',
#     'address3': None,
#     'city': 'Hanover',
#     'zip_code': '03755',
#     'country': 'US',
#     'state': 'NH',
#     'display_address': ['7 Lebanon St', 'Hanover, NH 03755']},
#    'phone': '+16032779102',
#    'display_phone': '(603) 277-9102',
#    'distance': 169.82167790259317,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1600',
#        'end': '2300',
#        'day': 0},
#       {'is_overnight': False, 'start': '1600', 'end': '2300', 'day': 1},
#       {'is_overnight': False, 'start': '1600', 'end': '2300', 'day': 2},
#       {'is_overnight': False, 'start': '1600', 'end': '2300', 'day': 3},
#       {'is_overnight': False, 'start': '1600', 'end': '0000', 'day': 4},
#       {'is_overnight': False, 'start': '1600', 'end': '0000', 'day': 5},
#       {'is_overnight': False, 'start': '1600', 'end': '2300', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '5vKVnel7PsD9Mv_Ki1tkUQ',
#    'alias': 'samosa-man-hanover',
#    'name': 'Samosa Man',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/samosa-man-hanover?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 6,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 43.70047, 'longitude': -72.28914},
#    'transactions': [],
#    'location': {'address1': '50 S Main St',
#     'address2': 'Unit 14',
#     'address3': None,
#     'city': 'Hanover',
#     'zip_code': '03755',
#     'country': 'US',
#     'state': 'NH',
#     'display_address': ['50 S Main St', 'Unit 14', 'Hanover, NH 03755']},
#    'phone': '+18022337783',
#    'display_phone': '(802) 233-7783',
#    'distance': 231.123140472225,
#    'business_hours': [],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}}],
#  'total': 28,
#  'region': {'center': {'longitude': -72.28634834289551,
#    'latitude': 43.70076799496142}}}

# %%
## example business
yelp_genjson['businesses'][0]

## more automatic way of summarizing but things end up in lists
## within columns for things like categories
yelp_gendf = pd.DataFrame(yelp_genjson['businesses'])
yelp_gendf.head()
# Out:
# {'id': 'XVGEEIH5rVB2QzW-qywcJw',
#  'alias': 'base-camp-cafe-hanover',
#  'name': 'Base Camp Cafe',
#  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/p8_YiEQI7p_JF82eaWa9Xg/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/base-camp-cafe-hanover?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#  'review_count': 252,
#  'categories': [{'alias': 'himalayan', 'title': 'Himalayan/Nepalese'}],
#  'rating': 4.4,
#  'coordinates': {'latitude': 43.700626, 'longitude': -72.2887803},
#  'transactions': ['delivery'],
#  'price': '$$',
#  'location': {'address1': '3 Lebanon St',
#   'address2': 'Ste 13',
#   'address3': '',
#   'city': 'Hanover',
#   'zip_code': '03755',
#   'country': 'US',
#   'state': 'NH',
#   'display_address': ['3 Lebanon St', 'Ste 13', 'Hanover, NH 03755']},
#  'phone': '+16036432007',
#  'display_phone': '(603) 643-2007',
#  'distance': 196.1397581876442,
#  'business_hours': [{'open': [{'is_overnight': False,
#      'start': '1100',
#      'end': '2100',
#      'day': 1},
#     {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 2},
#     {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 3},
#     {'is_overnight': False, 'start': '1100', 'end': '2130', 'day': 4},
#     {'is_overnight': False, 'start': '1100', 'end': '2130', 'day': 5},
#     {'is_overnight': False, 'start': '1100', 'end': '2100', 'day': 6}],
#    'hours_type': 'REGULAR',
#    'is_open_now': True}],
#  'attributes': {'business_temp_closed': None,
#   'menu_url': 'http://basecampcafenewhampshire.com/menu/',
#   'open24_hours': None,
#   'waitlist_reservation': None}}
#                        id                              alias  \
# 0  XVGEEIH5rVB2QzW-qywcJw             base-camp-cafe-hanover
# 1  8ybF6YyRldtZmU9jil4xlg  mollys-restaurant-and-bar-hanover
# 2  qxm3VNmD0O2zw8m9U8SxZg                   duende-hanover-2
# 3  5WW4g_LRwau29KyjZGLyAA           sawtooth-kitchen-hanover
# 4  wyV_NfYn4ZOfp_sHMDPcAw              bistro-at-six-hanover
#
#                        name  \
# 0            Base Camp Cafe
# 1  Molly's Restaurant & Bar
# 2                    Duende
# 3          Sawtooth Kitchen
# 4             Bistro at Six
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/p8_YiE...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/TJLrrA...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/rf_h2D...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/61MNG4...      False
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/i4jvss...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/base-camp-cafe-hanove...           252
# 1  https://www.yelp.com/biz/mollys-restaurant-and...           545
# 2  https://www.yelp.com/biz/duende-hanover-2?adju...            15
# 3  https://www.yelp.com/biz/sawtooth-kitchen-hano...            29
# 4  https://www.yelp.com/biz/bistro-at-six-hanover...             2
#
#                                           categories  rating  \
# 0  [{'alias': 'himalayan', 'title': 'Himalayan/Ne...     4.4
# 1  [{'alias': 'tradamerican', 'title': 'American'...     3.9
# 2  [{'alias': 'spanish', 'title': 'Spanish'}, {'a...     3.7
# 3  [{'alias': 'chickenshop', 'title': 'Chicken Sh...     4.1
# 4  [{'alias': 'lounges', 'title': 'Lounges'}, {'a...     4.0
#
#                                          coordinates transactions price  \
# 0  {'latitude': 43.700626, 'longitude': -72.2887803}   [delivery]    $$
# 1  {'latitude': 43.701144, 'longitude': -72.2894249}   [delivery]    $$
# 2  {'latitude': 43.70074272457673, 'longitude': -...           []   NaN
# 3    {'latitude': 43.70158, 'longitude': -72.289641}           []   NaN
# 4  {'latitude': 43.7001146, 'longitude': -72.2877...           []    $$
#
#                                             location         phone  \
# 0  {'address1': '3 Lebanon St', 'address2': 'Ste ...  +16036432007
# 1  {'address1': '43 South Main St', 'address2': '...  +16036432570
# 2  {'address1': '15 Lebanon St', 'address2': '', ...  +16033064826
# 3  {'address1': '33 S Main St', 'address2': '', '...  +16036435134
# 4  {'address1': '6 E South St', 'address2': None,...  +16036430600
#
#     display_phone    distance  \
# 0  (603) 643-2007  196.139758
# 1  (603) 643-2570  250.830160
# 2  (603) 306-4826  107.388862
# 3  (603) 643-5134  242.607552
# 4  (603) 643-0600  198.651788
#
#                                       business_hours  \
# 0  [{'open': [{'is_overnight': False, 'start': '1...
# 1  [{'open': [{'is_overnight': False, 'start': '1...
# 2  [{'open': [{'is_overnight': False, 'start': '1...
# 3  [{'open': [{'is_overnight': False, 'start': '1...
# 4  [{'open': [{'is_overnight': True, 'start': '00...
#
#                                           attributes
# 0  {'business_temp_closed': None, 'menu_url': 'ht...
# 1  {'business_temp_closed': None, 'menu_url': 'ht...
# 2  {'business_temp_closed': None, 'menu_url': 'ht...
# 3  {'business_temp_closed': None, 'menu_url': 'ht...
# 4  {'business_temp_closed': None, 'menu_url': Non...

# %%
## more data-specific way of summarizing
## we're doing a simple approach and just retaining
## cols that have a simple str structure
## if doing for real, would want to extract things
def clean_yelp_json(one_biz):

    ## restrict to str cols
    d_str = {key:value for key, value in one_biz.items()
             if type(value) == str}
    
    df_str = pd.DataFrame(d_str, index = [d_str['id']])
    return(df_str)

yelp_stronly = [clean_yelp_json(one_b) for one_b in yelp_genjson['businesses']]
yelp_stronly_df = pd.concat(yelp_stronly)

yelp_stronly_df.head(7)
# Out:
#                                             id  \
# XVGEEIH5rVB2QzW-qywcJw  XVGEEIH5rVB2QzW-qywcJw
# 8ybF6YyRldtZmU9jil4xlg  8ybF6YyRldtZmU9jil4xlg
# qxm3VNmD0O2zw8m9U8SxZg  qxm3VNmD0O2zw8m9U8SxZg
# 5WW4g_LRwau29KyjZGLyAA  5WW4g_LRwau29KyjZGLyAA
# wyV_NfYn4ZOfp_sHMDPcAw  wyV_NfYn4ZOfp_sHMDPcAw
# KA8yhrd-ClVYMyOefXdVYg  KA8yhrd-ClVYMyOefXdVYg
# 34j_2nRCVQBTKafJvncZlg  34j_2nRCVQBTKafJvncZlg
#
#                                                      alias  \
# XVGEEIH5rVB2QzW-qywcJw              base-camp-cafe-hanover
# 8ybF6YyRldtZmU9jil4xlg   mollys-restaurant-and-bar-hanover
# qxm3VNmD0O2zw8m9U8SxZg                    duende-hanover-2
# 5WW4g_LRwau29KyjZGLyAA            sawtooth-kitchen-hanover
# wyV_NfYn4ZOfp_sHMDPcAw               bistro-at-six-hanover
# KA8yhrd-ClVYMyOefXdVYg  lous-restaurant-and-bakery-hanover
# 34j_2nRCVQBTKafJvncZlg           pine-restaurant-hanover-2
#
#                                              name  \
# XVGEEIH5rVB2QzW-qywcJw             Base Camp Cafe
# 8ybF6YyRldtZmU9jil4xlg   Molly's Restaurant & Bar
# qxm3VNmD0O2zw8m9U8SxZg                     Duende
# 5WW4g_LRwau29KyjZGLyAA           Sawtooth Kitchen
# wyV_NfYn4ZOfp_sHMDPcAw              Bistro at Six
# KA8yhrd-ClVYMyOefXdVYg  Lou's Restaurant & Bakery
# 34j_2nRCVQBTKafJvncZlg            PINE Restaurant
#
#                                                                 image_url  \
# XVGEEIH5rVB2QzW-qywcJw  https://s3-media1.fl.yelpcdn.com/bphoto/p8_YiE...
# 8ybF6YyRldtZmU9jil4xlg  https://s3-media4.fl.yelpcdn.com/bphoto/TJLrrA...
# qxm3VNmD0O2zw8m9U8SxZg  https://s3-media4.fl.yelpcdn.com/bphoto/rf_h2D...
# 5WW4g_LRwau29KyjZGLyAA  https://s3-media3.fl.yelpcdn.com/bphoto/61MNG4...
# wyV_NfYn4ZOfp_sHMDPcAw  https://s3-media2.fl.yelpcdn.com/bphoto/i4jvss...
# KA8yhrd-ClVYMyOefXdVYg  https://s3-media3.fl.yelpcdn.com/bphoto/VAx8H9...
# 34j_2nRCVQBTKafJvncZlg  https://s3-media3.fl.yelpcdn.com/bphoto/c2SgUR...
#
#                                                                       url  \
# XVGEEIH5rVB2QzW-qywcJw  https://www.yelp.com/biz/base-camp-cafe-hanove...
# 8ybF6YyRldtZmU9jil4xlg  https://www.yelp.com/biz/mollys-restaurant-and...
# qxm3VNmD0O2zw8m9U8SxZg  https://www.yelp.com/biz/duende-hanover-2?adju...
# 5WW4g_LRwau29KyjZGLyAA  https://www.yelp.com/biz/sawtooth-kitchen-hano...
# wyV_NfYn4ZOfp_sHMDPcAw  https://www.yelp.com/biz/bistro-at-six-hanover...
# KA8yhrd-ClVYMyOefXdVYg  https://www.yelp.com/biz/lous-restaurant-and-b...
# 34j_2nRCVQBTKafJvncZlg  https://www.yelp.com/biz/pine-restaurant-hanov...
#
#                        price         phone   display_phone
# XVGEEIH5rVB2QzW-qywcJw    $$  +16036432007  (603) 643-2007
# 8ybF6YyRldtZmU9jil4xlg    $$  +16036432570  (603) 643-2570
# qxm3VNmD0O2zw8m9U8SxZg   NaN  +16033064826  (603) 306-4826
# 5WW4g_LRwau29KyjZGLyAA   NaN  +16036435134  (603) 643-5134
# wyV_NfYn4ZOfp_sHMDPcAw    $$  +16036430600  (603) 643-0600
# KA8yhrd-ClVYMyOefXdVYg    $$  +16036433321  (603) 643-3321
# 34j_2nRCVQBTKafJvncZlg   $$$  +16036468000  (603) 646-8000

# %% [markdown]
# # Activity 2: pull restaurants in a different location
#
# - Try running a business search query for your hometown or another place by constructing a query similar to `yelp_genquery` but changing the location parameter
# - Other endpoints require feeding what's called the business' fusion id into the API. Take an id from `yelp_stronly.id` and use the documentation here to pull the reviews for that business: https://docs.developer.yelp.com/reference/v3_business_reviews
# - **Challenge**: generalize the previous step by writing a function that (1) takes a list of business ids as an input, (2) calls the reviews API for each id, (3) returns the results, and (4) rowbinds all results, i.e. turns them into a single, usable DataFrame

# %%
## write the query 
base_url = "https://api.yelp.com/v3/businesses/search?"
my_name = "restaurants"
my_location = "Osaka, Osaka Prefecture, Japan"
yelp_genquery = ('{base_url}'
                'term={name}'
                '&location={loc}').format(base_url = base_url,
                name = my_name,
                loc = my_location)

yelp_genquery
# Out:
# 'https://api.yelp.com/v3/businesses/search?term=restaurants&location=Osaka, Osaka Prefecture, Japan'

# %%
header = {'Authorization': f"Bearer {API_KEY}"}
yelp_genresp = requests.get(yelp_genquery, headers = header)
yelp_genresp

## then, look at structure of response
yelp_genjson = yelp_genresp.json()
yelp_genjson
# Out:
# <Response [200]>
# {'businesses': [{'id': 'Gzv9XsUt-62RbIsc9173rw',
#    'alias': '牛かつもと村-難波店-大阪市-2',
#    'name': 'Gyuukatsu Motomura Namba',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/L0_3ATRt7ehsG5kFN8bszA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E7%89%9B%E3%81%8B%E3%81%A4%E3%82%82%E3%81%A8%E6%9D%91-%E9%9B%A3%E6%B3%A2%E5%BA%97-%E5%A4%A7%E9%98%AA%E5%B8%82-2?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 71,
#    'categories': [{'alias': 'tempura', 'title': 'Tempura'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.8,
#    'coordinates': {'latitude': 34.666573, 'longitude': 135.502009},
#    'transactions': [],
#    'price': '￥',
#    'location': {'address1': '中央区難波3-3-1',
#     'address2': '',
#     'address3': '',
#     'city': 'Osaka',
#     'zip_code': '542-0076',
#     'country': 'JP',
#     'state': '27',
#     'display_address': ['中央区難波3-3-1', 'Osaka, 大阪府 〒542-0076', 'Japan']},
#    'phone': '+81666433313',
#    'display_phone': '+81 6-6643-3313',
#    'distance': 1857.7735952832786,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1100',
#        'end': '2300',
#        'day': 0},
#       {'is_overnight': False, 'start': '1100', 'end': '2300', 'day': 1},
#       {'is_overnight': False, 'start': '1100', 'end': '2300', 'day': 2},
#       {'is_overnight': False, 'start': '1100', 'end': '2300', 'day': 3},
#       {'is_overnight': False, 'start': '1100', 'end': '2300', 'day': 4},
#       {'is_overnight': False, 'start': '1100', 'end': '2300', 'day': 5},
#       {'is_overnight': False, 'start': '1100', 'end': '2300', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'PlArwOQJ79AJEVIFPtk3KA',
#    'alias': '一蘭-道頓堀店本館-大阪市',
#    'name': 'ICHIRAN Dotonbori',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/z_WoCWB6XTEsODpEnvYHiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E4%B8%80%E8%98%AD-%E9%81%93%E9%A0%93%E5%A0%80%E5%BA%97%E6%9C%AC%E9%A4%A8-%E5%A4%A7%E9%98%AA%E5%B8%82?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 283,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 34.669212, 'longitude': 135.503039},
#    'transactions': [],
#    'price': '￥',
#    'location': {'address1': '中央区宗右衛門町7-18',
#     'address2': '田舎そばビル 1F',
#     'address3': None,
#     'city': 'Osaka',
#     'zip_code': '542-0084',
#     'country': 'JP',
#     'state': '27',
#     'display_address': ['中央区宗右衛門町7-18',
#      '田舎そばビル 1F',
#      'Osaka, 大阪府 〒542-0084',
#      'Japan']},
#    'phone': '+815018082557',
#    'display_phone': '+81 50-1808-2557',
#    'distance': 1740.4237787786328,
#    'business_hours': [{'open': [{'is_overnight': True,
#        'start': '0000',
#        'end': '0000',
#        'day': 0},
#       {'is_overnight': True, 'start': '0000', 'end': '0000', 'day': 1},
#       {'is_overnight': True, 'start': '0000', 'end': '0000', 'day': 2},
#       {'is_overnight': True, 'start': '0000', 'end': '0000', 'day': 3},
#       {'is_overnight': True, 'start': '0000', 'end': '0000', 'day': 4},
#       {'is_overnight': True, 'start': '0000', 'end': '0000', 'day': 5},
#       {'is_overnight': True, 'start': '0000', 'end': '0000', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.ichiran.co.jp/oshinagaki/oshinagaki.html',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'urKTDMFD2OS28iBH6pPSUA',
#    'alias': 'お好み焼き-ちとせ-大阪市-2',
#    'name': 'Okonomiyaki Chitose',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wG7f5NJct8X_ZBpa30Hl2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E3%81%8A%E5%A5%BD%E3%81%BF%E7%84%BC%E3%81%8D-%E3%81%A1%E3%81%A8%E3%81%9B-%E5%A4%A7%E9%98%AA%E5%B8%82-2?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 78,
#    'categories': [{'alias': 'okonomiyaki', 'title': 'Okonomiyaki'},
#     {'alias': 'teppanyaki', 'title': 'Teppanyaki'},
#     {'alias': 'soba', 'title': 'Soba'}],
#    'rating': 4.8,
#    'coordinates': {'latitude': 34.64751, 'longitude': 135.504734},
#    'transactions': [],
#    'price': '￥',
#    'location': {'address1': '西成区太子1-11-10',
#     'address2': '',
#     'address3': '',
#     'city': 'Osaka',
#     'zip_code': '557-0002',
#     'country': 'JP',
#     'state': '27',
#     'display_address': ['西成区太子1-11-10', 'Osaka, 大阪府 〒557-0002', 'Japan']},
#    'phone': '+81666316002',
#    'display_phone': '+81 6-6631-6002',
#    'distance': 3768.3348435112907,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1200',
#        'end': '2100',
#        'day': 0},
#       {'is_overnight': False, 'start': '1200', 'end': '2100', 'day': 1},
#       {'is_overnight': False, 'start': '1200', 'end': '2100', 'day': 3},
#       {'is_overnight': False, 'start': '1200', 'end': '2100', 'day': 4},
#       {'is_overnight': False, 'start': '1200', 'end': '2100', 'day': 5},
#       {'is_overnight': False, 'start': '1200', 'end': '2100', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': '',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'FIvbrH1rMC3uudv2O18L-w',
#    'alias': 'じねん-鰻谷南通り店-大阪市-2',
#    'name': 'Jinen Unagidani Minamitori',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nE7adN8hGdEfasp5S2NDWw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E3%81%98%E3%81%AD%E3%82%93-%E9%B0%BB%E8%B0%B7%E5%8D%97%E9%80%9A%E3%82%8A%E5%BA%97-%E5%A4%A7%E9%98%AA%E5%B8%82-2?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 80,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 34.674264, 'longitude': 135.50455},
#    'transactions': [],
#    'price': '￥￥',
#    'location': {'address1': '中央区東心斎橋1-8-26',
#     'address2': None,
#     'address3': None,
#     'city': 'Osaka',
#     'zip_code': '542-0083',
#     'country': 'JP',
#     'state': '27',
#     'display_address': ['中央区東心斎橋1-8-26', 'Osaka, 大阪府 〒542-0083', 'Japan']},
#    'phone': '+81662444111',
#    'display_phone': '+81 6-6244-4111',
#    'distance': 1617.9801376246014,
#    'business_hours': [{'open': [{'is_overnight': True,
#        'start': '1100',
#        'end': '0400',
#        'day': 0},
#       {'is_overnight': True, 'start': '1100', 'end': '0400', 'day': 1},
#       {'is_overnight': True, 'start': '1100', 'end': '0400', 'day': 2},
#       {'is_overnight': True, 'start': '1100', 'end': '0400', 'day': 3},
#       {'is_overnight': True, 'start': '1100', 'end': '0400', 'day': 4},
#       {'is_overnight': True, 'start': '1100', 'end': '0400', 'day': 5},
#       {'is_overnight': True, 'start': '1100', 'end': '0400', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://jinen.org/product/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'tmWKNG4osApqN2GQjaaeeg',
#    'alias': '松阪牛焼肉-m-法善寺横丁店-大阪市',
#    'name': 'Matsusakagyu Yakiniku M Hozenji Yokocho ',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3JqV_ozfwahDqW78xdkXpg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E6%9D%BE%E9%98%AA%E7%89%9B%E7%84%BC%E8%82%89-m-%E6%B3%95%E5%96%84%E5%AF%BA%E6%A8%AA%E4%B8%81%E5%BA%97-%E5%A4%A7%E9%98%AA%E5%B8%82?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 133,
#    'categories': [{'alias': 'yakiniku', 'title': 'Yakiniku'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.6,
#    'coordinates': {'latitude': 34.668139, 'longitude': 135.502569},
#    'transactions': [],
#    'price': '￥￥￥',
#    'location': {'address1': '中央区難波1-1-19',
#     'address2': '',
#     'address3': None,
#     'city': 'Osaka',
#     'zip_code': '542-0076',
#     'country': 'JP',
#     'state': '27',
#     'display_address': ['中央区難波1-1-19', 'Osaka, 大阪府 〒542-0076', 'Japan']},
#    'phone': '+81662112917',
#    'display_phone': '+81 6-6211-2917',
#    'distance': 1779.0341954402295,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1700',
#        'end': '0000',
#        'day': 0},
#       {'is_overnight': False, 'start': '1700', 'end': '0000', 'day': 1},
#       {'is_overnight': False, 'start': '1700', 'end': '0000', 'day': 2},
#       {'is_overnight': False, 'start': '1700', 'end': '0000', 'day': 3},
#       {'is_overnight': False, 'start': '1700', 'end': '0000', 'day': 4},
#       {'is_overnight': False, 'start': '1200', 'end': '1500', 'day': 5},
#       {'is_overnight': False, 'start': '1700', 'end': '0000', 'day': 5},
#       {'is_overnight': False, 'start': '1200', 'end': '1500', 'day': 6},
#       {'is_overnight': False, 'start': '1700', 'end': '0000', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.matsusaka-projects.com/restaurant/yokocho/',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'ZwTES2XA64a9S300NiQXoQ',
#    'alias': '漁火-大阪市-北区-2',
#    'name': 'Isaribi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1NjVXMTo2S_pyWyOw8nNfQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E6%BC%81%E7%81%AB-%E5%A4%A7%E9%98%AA%E5%B8%82-%E5%8C%97%E5%8C%BA-2?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 28,
#    'categories': [{'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'robatayaki', 'title': 'Robatayaki'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 34.706464, 'longitude': 135.497568},
#    'transactions': [],
#    'price': '￥￥',
#    'location': {'address1': '芝田1丁目5-12',
#     'address2': '備後屋ビル',
#     'address3': None,
#     'city': '大阪市 北区',
#     'zip_code': '530-0012',
#     'country': 'JP',
#     'state': '27',
#     'display_address': ['芝田1丁目5-12',
#      '備後屋ビル',
#      '大阪市 北区, 大阪府 〒530-0012',
#      'Japan']},
#    'phone': '+81663732969',
#    'display_phone': '+81 6-6373-2969',
#    'distance': 3261.3092132727206,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1700',
#        'end': '2330',
#        'day': 0},
#       {'is_overnight': False, 'start': '1700', 'end': '2330', 'day': 1},
#       {'is_overnight': False, 'start': '1700', 'end': '2330', 'day': 2},
#       {'is_overnight': False, 'start': '1700', 'end': '2330', 'day': 3},
#       {'is_overnight': False, 'start': '1700', 'end': '2330', 'day': 4},
#       {'is_overnight': False, 'start': '1630', 'end': '2330', 'day': 5},
#       {'is_overnight': False, 'start': '1630', 'end': '2330', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'MBnY4vzd77nyyB5Dg0IpWw',
#    'alias': '花丸軒-法善寺店-大阪市',
#    'name': 'Hanamaruken Hozenji',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aIL8uLD6jS2FiknFSgDS0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E8%8A%B1%E4%B8%B8%E8%BB%92-%E6%B3%95%E5%96%84%E5%AF%BA%E5%BA%97-%E5%A4%A7%E9%98%AA%E5%B8%82?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 81,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'dumplings', 'title': 'Dumplings'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 34.667904, 'longitude': 135.503075},
#    'transactions': [],
#    'price': '￥',
#    'location': {'address1': '中央区難波1-2-1',
#     'address2': None,
#     'address3': None,
#     'city': 'Osaka',
#     'zip_code': '542-0076',
#     'country': 'JP',
#     'state': '27',
#     'display_address': ['中央区難波1-2-1', 'Osaka, 大阪府 〒542-0076', 'Japan']},
#    'phone': '+81662130131',
#    'display_phone': '+81 6-6213-0131',
#    'distance': 1831.3871880994786,
#    'business_hours': [{'open': [{'is_overnight': True,
#        'start': '0900',
#        'end': '0900',
#        'day': 0},
#       {'is_overnight': True, 'start': '0900', 'end': '0900', 'day': 1},
#       {'is_overnight': True, 'start': '0900', 'end': '0900', 'day': 2},
#       {'is_overnight': True, 'start': '0900', 'end': '0900', 'day': 3},
#       {'is_overnight': True, 'start': '0900', 'end': '0900', 'day': 4},
#       {'is_overnight': True, 'start': '0900', 'end': '0900', 'day': 5},
#       {'is_overnight': True, 'start': '0900', 'end': '0900', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'UCJ50_Wek_Jkk80UvbVUmg',
#    'alias': '市場ずし-心斎橋店-大阪市',
#    'name': 'Ichibazushi shinsaibashi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AX2LmGezRw6UX0EUUCReqA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E5%B8%82%E5%A0%B4%E3%81%9A%E3%81%97-%E5%BF%83%E6%96%8E%E6%A9%8B%E5%BA%97-%E5%A4%A7%E9%98%AA%E5%B8%82?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 23,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.6,
#    'coordinates': {'latitude': 34.6708819, 'longitude': 135.5010909},
#    'transactions': [],
#    'price': '￥',
#    'location': {'address1': '中央区心斎橋筋2-7-3',
#     'address2': '',
#     'address3': None,
#     'city': 'Osaka',
#     'zip_code': '542-0085',
#     'country': 'JP',
#     'state': '27',
#     'display_address': ['中央区心斎橋筋2-7-3', 'Osaka, 大阪府 〒542-0085', 'Japan']},
#    'phone': '+81662119070',
#    'display_phone': '+81 6-6211-9070',
#    'distance': 1488.2645134185311,
#    'business_hours': [{'open': [{'is_overnight': True,
#        'start': '1200',
#        'end': '0500',
#        'day': 0},
#       {'is_overnight': True, 'start': '1200', 'end': '0500', 'day': 1},
#       {'is_overnight': True, 'start': '1200', 'end': '0500', 'day': 2},
#       {'is_overnight': True, 'start': '1200', 'end': '0500', 'day': 3},
#       {'is_overnight': True, 'start': '1200', 'end': '0500', 'day': 4},
#       {'is_overnight': True, 'start': '1200', 'end': '0500', 'day': 5},
#       {'is_overnight': True, 'start': '1200', 'end': '0500', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://ichibazushi.com/menu.html',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'IvD7ixME4HW5W3EhbsKQ9g',
#    'alias': '神戸牛すてーき-健-大阪市',
#    'name': 'Kobegyu Steak Ken ',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Cruhc1jPvCSVkoLhjVOKKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E7%A5%9E%E6%88%B8%E7%89%9B%E3%81%99%E3%81%A6%E3%83%BC%E3%81%8D-%E5%81%A5-%E5%A4%A7%E9%98%AA%E5%B8%82?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 27,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'teppanyaki', 'title': 'Teppanyaki'}],
#    'rating': 4.9,
#    'coordinates': {'latitude': 34.6698994561547,
#     'longitude': 135.502127985731},
#    'transactions': [],
#    'price': '￥￥￥￥',
#    'location': {'address1': '中央区心斎橋筋2-3-5',
#     'address2': '日宝ファインプラザ 2F',
#     'address3': None,
#     'city': 'Osaka',
#     'zip_code': '542-0085',
#     'country': 'JP',
#     'state': '27',
#     'display_address': ['中央区心斎橋筋2-3-5',
#      '日宝ファインプラザ 2F',
#      'Osaka, 大阪府 〒542-0085',
#      'Japan']},
#    'phone': '+81662145656',
#    'display_phone': '+81 6-6214-5656',
#    'distance': 1628.250517341751,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1200',
#        'end': '1400',
#        'day': 0},
#       {'is_overnight': False, 'start': '1600', 'end': '2300', 'day': 0},
#       {'is_overnight': False, 'start': '1200', 'end': '1400', 'day': 1},
#       {'is_overnight': False, 'start': '1600', 'end': '2300', 'day': 1},
#       {'is_overnight': False, 'start': '1200', 'end': '1400', 'day': 2},
#       {'is_overnight': False, 'start': '1600', 'end': '2300', 'day': 2},
#       {'is_overnight': False, 'start': '1200', 'end': '1400', 'day': 3},
#       {'is_overnight': False, 'start': '1600', 'end': '2300', 'day': 3},
#       {'is_overnight': False, 'start': '1200', 'end': '1400', 'day': 4},
#       {'is_overnight': False, 'start': '1600', 'end': '2300', 'day': 4},
#       {'is_overnight': False, 'start': '1200', 'end': '1400', 'day': 5},
#       {'is_overnight': False, 'start': '1600', 'end': '2300', 'day': 5}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'rTJuG3rzpw4sBL567R97Uw',
#    'alias': '万両-南森町店-大阪市-2',
#    'name': 'Manryou Minami Morimachi',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GEltuD6f2s1XzVCK8EykoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E4%B8%87%E4%B8%A1-%E5%8D%97%E6%A3%AE%E7%94%BA%E5%BA%97-%E5%A4%A7%E9%98%AA%E5%B8%82-2?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 27,
#    'categories': [{'alias': 'yakiniku', 'title': 'Yakiniku'},
#     {'alias': 'horumon', 'title': 'Horumon'}],
#    'rating': 4.7,
#    'coordinates': {'latitude': 34.696318, 'longitude': 135.509716},
#    'transactions': [],
#    'price': '￥￥',
#    'location': {'address1': '北区南森町1-2-14',
#     'address2': 'ロイヤルハイツ 1F',
#     'address3': None,
#     'city': 'Osaka',
#     'zip_code': '530-0054',
#     'country': 'JP',
#     'state': '27',
#     'display_address': ['北区南森町1-2-14',
#      'ロイヤルハイツ 1F',
#      'Osaka, 大阪府 〒530-0054',
#      'Japan']},
#    'phone': '+81663611371',
#    'display_phone': '+81 6-6361-1371',
#    'distance': 2848.426520414709,
#    'business_hours': [{'open': [{'is_overnight': True,
#        'start': '1700',
#        'end': '0100',
#        'day': 0},
#       {'is_overnight': True, 'start': '1700', 'end': '0100', 'day': 1},
#       {'is_overnight': True, 'start': '1700', 'end': '0100', 'day': 2},
#       {'is_overnight': True, 'start': '1700', 'end': '0100', 'day': 3},
#       {'is_overnight': True, 'start': '1700', 'end': '0100', 'day': 4},
#       {'is_overnight': False, 'start': '1700', 'end': '0000', 'day': 5},
#       {'is_overnight': False, 'start': '1700', 'end': '0000', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '53EVFkUFiavvqpIoyBKzYg',
#    'alias': '大起水産回転寿司-天満橋店-大阪市',
#    'name': 'Daikisuisan Kaitenzushi Tenmabashi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/19esJ1dXFsi_tkEH9XHprg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E5%A4%A7%E8%B5%B7%E6%B0%B4%E7%94%A3%E5%9B%9E%E8%BB%A2%E5%AF%BF%E5%8F%B8-%E5%A4%A9%E6%BA%80%E6%A9%8B%E5%BA%97-%E5%A4%A7%E9%98%AA%E5%B8%82?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 17,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'conveyorsushi', 'title': 'Conveyor Belt Sushi'},
#     {'alias': 'tempura', 'title': 'Tempura'}],
#    'rating': 4.6,
#    'coordinates': {'latitude': 34.690012, 'longitude': 135.516254},
#    'transactions': [],
#    'price': '￥￥',
#    'location': {'address1': '中央区天満橋京町1-1',
#     'address2': '京阪シティモール 8F',
#     'address3': None,
#     'city': 'Osaka',
#     'zip_code': '540-0032',
#     'country': 'JP',
#     'state': '27',
#     'display_address': ['中央区天満橋京町1-1',
#      '京阪シティモール 8F',
#      'Osaka, 大阪府 〒540-0032',
#      'Japan']},
#    'phone': '+81669403075',
#    'display_phone': '+81 6-6940-3075',
#    'distance': 2928.809212536535,
#    'business_hours': [],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'xurofyvHzduPFkSV2ce2bw',
#    'alias': 'かすうどん-加寿屋-法善寺-大阪市',
#    'name': 'Kasu Udon Kasuya Hozenji',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ekgvav1pXWbYEFsqPMhQtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E3%81%8B%E3%81%99%E3%81%86%E3%81%A9%E3%82%93-%E5%8A%A0%E5%AF%BF%E5%B1%8B-%E6%B3%95%E5%96%84%E5%AF%BA-%E5%A4%A7%E9%98%AA%E5%B8%82?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 29,
#    'categories': [{'alias': 'udon', 'title': 'Udon'}],
#    'rating': 4.8,
#    'coordinates': {'latitude': 34.6677772939795,
#     'longitude': 135.501760687103},
#    'transactions': [],
#    'price': '￥',
#    'location': {'address1': '中央区難波1-5-20',
#     'address2': None,
#     'address3': None,
#     'city': 'Osaka',
#     'zip_code': '542-0076',
#     'country': 'JP',
#     'state': '27',
#     'display_address': ['中央区難波1-5-20', 'Osaka, 大阪府 〒542-0076', 'Japan']},
#    'phone': '+81662111291',
#    'display_phone': '+81 6-6211-1291',
#    'distance': 1749.3090199700498,
#    'business_hours': [{'open': [{'is_overnight': True,
#        'start': '1100',
#        'end': '0500',
#        'day': 0},
#       {'is_overnight': True, 'start': '1100', 'end': '0500', 'day': 1},
#       {'is_overnight': True, 'start': '1100', 'end': '0500', 'day': 2},
#       {'is_overnight': True, 'start': '1100', 'end': '0500', 'day': 3},
#       {'is_overnight': True, 'start': '1100', 'end': '0500', 'day': 4},
#       {'is_overnight': True, 'start': '1100', 'end': '0500', 'day': 5},
#       {'is_overnight': True, 'start': '1100', 'end': '0500', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.kasu-kasuya.com/menu/menu.html',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'U38Ws_u5G55j5PDj4GxDAA',
#    'alias': 'ずんどう屋-心斎橋店-大阪市',
#    'name': 'ZUNDO-YA Shinsaibashi',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CGpnact_zc9coQJOId20SQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E3%81%9A%E3%82%93%E3%81%A9%E3%81%86%E5%B1%8B-%E5%BF%83%E6%96%8E%E6%A9%8B%E5%BA%97-%E5%A4%A7%E9%98%AA%E5%B8%82?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 51,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'dumplings', 'title': 'Dumplings'},
#     {'alias': 'donburi', 'title': 'Donburi'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 34.672016, 'longitude': 135.50197},
#    'transactions': [],
#    'price': '￥',
#    'location': {'address1': '中央区心斎橋筋1-5-7',
#     'address2': 'セーナビル 1F',
#     'address3': '',
#     'city': 'Osaka',
#     'zip_code': '542-0085',
#     'country': 'JP',
#     'state': '27',
#     'display_address': ['中央区心斎橋筋1-5-7',
#      'セーナビル 1F',
#      'Osaka, 大阪府 〒542-0085',
#      'Japan']},
#    'phone': '+81662450883',
#    'display_phone': '+81 6-6245-0883',
#    'distance': 1492.6045857665613,
#    'business_hours': [{'open': [{'is_overnight': True,
#        'start': '0900',
#        'end': '0900',
#        'day': 0},
#       {'is_overnight': True, 'start': '0900', 'end': '0900', 'day': 1},
#       {'is_overnight': True, 'start': '0900', 'end': '0900', 'day': 2},
#       {'is_overnight': True, 'start': '0900', 'end': '0900', 'day': 3},
#       {'is_overnight': True, 'start': '0900', 'end': '0900', 'day': 4},
#       {'is_overnight': True, 'start': '0900', 'end': '0900', 'day': 5},
#       {'is_overnight': True, 'start': '0900', 'end': '0900', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://www.zundouya.com/foodsindex.html',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'NHlstHZHzXNJN7p-69qeKg',
#    'alias': 'red-rock-アメ村店-大阪市',
#    'name': 'Red Rock Ame Mura',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/QSgOjfbuAObgD6qewTRiQg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/red-rock-%E3%82%A2%E3%83%A1%E6%9D%91%E5%BA%97-%E5%A4%A7%E9%98%AA%E5%B8%82?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 12,
#    'categories': [{'alias': 'gyudon', 'title': 'Gyudon'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.8,
#    'coordinates': {'latitude': 34.6713104248047,
#     'longitude': 135.498336791992},
#    'transactions': [],
#    'price': '￥',
#    'location': {'address1': '中央区西心斎橋2-10-21',
#     'address2': 'スパジオビル1階',
#     'address3': '',
#     'city': 'Osaka',
#     'zip_code': '542-0086',
#     'country': 'JP',
#     'state': '27',
#     'display_address': ['中央区西心斎橋2-10-21',
#      'スパジオビル1階',
#      'Osaka, 大阪府 〒542-0086',
#      'Japan']},
#    'phone': '+81662148119',
#    'display_phone': '+81 6-6214-8119',
#    'distance': 1260.7919079056735,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1130',
#        'end': '2300',
#        'day': 0},
#       {'is_overnight': False, 'start': '1130', 'end': '2300', 'day': 1},
#       {'is_overnight': False, 'start': '1130', 'end': '2300', 'day': 2},
#       {'is_overnight': False, 'start': '1130', 'end': '2300', 'day': 3},
#       {'is_overnight': False, 'start': '1130', 'end': '2300', 'day': 4},
#       {'is_overnight': False, 'start': '1130', 'end': '2300', 'day': 5},
#       {'is_overnight': False, 'start': '1130', 'end': '2300', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '-r7qzuFddfbsvze5z80qfw',
#    'alias': '幸せのパンケーキ-心斎橋店-大阪市',
#    'name': 'A HAPPY PANCAKE Shinsaibashi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_Aei5NrjhfrQnqRdrwtQrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E5%B9%B8%E3%81%9B%E3%81%AE%E3%83%91%E3%83%B3%E3%82%B1%E3%83%BC%E3%82%AD-%E5%BF%83%E6%96%8E%E6%A9%8B%E5%BA%97-%E5%A4%A7%E9%98%AA%E5%B8%82?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 64,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 34.671761, 'longitude': 135.498726},
#    'transactions': [],
#    'price': '￥',
#    'location': {'address1': '中央区西心斎橋2-10-32',
#     'address2': 'スマイルステップ\u3000B1F',
#     'address3': None,
#     'city': 'Osaka',
#     'zip_code': '542-0086',
#     'country': 'JP',
#     'state': '27',
#     'display_address': ['中央区西心斎橋2-10-32',
#      'スマイルステップ\u3000B1F',
#      'Osaka, 大阪府 〒542-0086',
#      'Japan']},
#    'phone': '+81662111000',
#    'display_phone': '+81 6-6211-1000',
#    'distance': 1254.7218436675814,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1000',
#        'end': '2000',
#        'day': 0},
#       {'is_overnight': False, 'start': '1000', 'end': '2000', 'day': 1},
#       {'is_overnight': False, 'start': '1000', 'end': '2000', 'day': 2},
#       {'is_overnight': False, 'start': '1000', 'end': '2000', 'day': 3},
#       {'is_overnight': False, 'start': '1000', 'end': '2000', 'day': 4},
#       {'is_overnight': False, 'start': '1000', 'end': '2030', 'day': 5},
#       {'is_overnight': False, 'start': '1000', 'end': '2030', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': 'http://magia.tokyo/menu',
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'IgKlwq2vnfARF6ocL-F0NA',
#    'alias': '餃子王-道頓堀店-大阪市',
#    'name': 'GYOZA OH! Dotonbori',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6VpXnFGLtNscV_RC2fZuHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E9%A4%83%E5%AD%90%E7%8E%8B-%E9%81%93%E9%A0%93%E5%A0%80%E5%BA%97-%E5%A4%A7%E9%98%AA%E5%B8%82?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 41,
#    'categories': [{'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'dumplings', 'title': 'Dumplings'}],
#    'rating': 4.7,
#    'coordinates': {'latitude': 34.66881, 'longitude': 135.498125},
#    'transactions': [],
#    'price': '￥',
#    'location': {'address1': '中央区道頓堀2-4-14',
#     'address2': '',
#     'address3': None,
#     'city': 'Osaka',
#     'zip_code': '540-0032',
#     'country': 'JP',
#     'state': '27',
#     'display_address': ['中央区道頓堀2-4-14', 'Osaka, 大阪府 〒540-0032', 'Japan']},
#    'phone': '+81662104403',
#    'display_phone': '+81 6-6210-4403',
#    'distance': 1432.1062273963455,
#    'business_hours': [{'open': [{'is_overnight': True,
#        'start': '1700',
#        'end': '0300',
#        'day': 0},
#       {'is_overnight': True, 'start': '1700', 'end': '0300', 'day': 1},
#       {'is_overnight': True, 'start': '1700', 'end': '0300', 'day': 2},
#       {'is_overnight': True, 'start': '1700', 'end': '0300', 'day': 3},
#       {'is_overnight': True, 'start': '1700', 'end': '0300', 'day': 4},
#       {'is_overnight': True, 'start': '1700', 'end': '0300', 'day': 5},
#       {'is_overnight': True, 'start': '1700', 'end': '0300', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': True}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': '6jMVetrQxwTeiaCcYPjJSg',
#    'alias': 'マルショー水産-大阪市-中央区',
#    'name': 'Marusho Suisan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/h2M-Mp6px5PoMIw8om9PyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E3%83%9E%E3%83%AB%E3%82%B7%E3%83%A7%E3%83%BC%E6%B0%B4%E7%94%A3-%E5%A4%A7%E9%98%AA%E5%B8%82-%E4%B8%AD%E5%A4%AE%E5%8C%BA?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 1,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'blowfish', 'title': 'Blowfish'},
#     {'alias': 'seafoodmarkets', 'title': 'Seafood Markets'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 34.6663620577736,
#     'longitude': 135.506812249163},
#    'transactions': [],
#    'location': {'address1': '日本橋1丁目177',
#     'address2': None,
#     'address3': None,
#     'city': '大阪市 中央区',
#     'zip_code': '542-0073',
#     'country': 'JP',
#     'state': '27',
#     'display_address': ['日本橋1丁目177', '大阪市 中央区, 大阪府 〒542-0073', 'Japan']},
#    'phone': '+81666446158',
#    'display_phone': '+81 6-6644-6158',
#    'distance': 2206.1809133263205,
#    'business_hours': [],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'u8QPZmlToTzQ07lVMtad4A',
#    'alias': '寿し花ざくら-大阪市',
#    'name': '寿し花ざくら',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VcJlHslLpXY8sY39FdKYfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E5%AF%BF%E3%81%97%E8%8A%B1%E3%81%96%E3%81%8F%E3%82%89-%E5%A4%A7%E9%98%AA%E5%B8%82?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 12,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.8,
#    'coordinates': {'latitude': 34.7045453433459,
#     'longitude': 135.488120643224},
#    'transactions': [],
#    'price': '￥￥',
#    'location': {'address1': '北区大淀中1-12-18',
#     'address2': 'シャトー大淀 1F',
#     'address3': None,
#     'city': 'Osaka',
#     'zip_code': '531-0076',
#     'country': 'JP',
#     'state': '27',
#     'display_address': ['北区大淀中1-12-18',
#      'シャトー大淀 1F',
#      'Osaka, 大阪府 〒531-0076',
#      'Japan']},
#    'phone': '+81664588336',
#    'display_phone': '+81 6-6458-8336',
#    'distance': 2917.3116212659806,
#    'business_hours': [],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'CioI7jszpKlG9YuTBvTPog',
#    'alias': '得正森之宮店-大阪市',
#    'name': 'Tokumasa Morinomiya',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/p543bgh7hbcJU1ELvrfCAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E5%BE%97%E6%AD%A3%E6%A3%AE%E4%B9%8B%E5%AE%AE%E5%BA%97-%E5%A4%A7%E9%98%AA%E5%B8%82?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 43,
#    'categories': [{'alias': 'udon', 'title': 'Udon'},
#     {'alias': 'japacurry', 'title': 'Japanese Curry'}],
#    'rating': 4.7,
#    'coordinates': {'latitude': 34.681263, 'longitude': 135.532428},
#    'transactions': [],
#    'price': '￥',
#    'location': {'address1': '中央区森ノ宮中央1-16-22',
#     'address2': '岡田ビル',
#     'address3': None,
#     'city': 'Osaka',
#     'zip_code': '540-0003',
#     'country': 'JP',
#     'state': '27',
#     'display_address': ['中央区森ノ宮中央1-16-22',
#      '岡田ビル',
#      'Osaka, 大阪府 〒540-0003',
#      'Japan']},
#    'phone': '+81669421903',
#    'display_phone': '+81 6-6942-1903',
#    'distance': 4116.262272940173,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '1100',
#        'end': '1600',
#        'day': 0},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 0},
#       {'is_overnight': False, 'start': '1100', 'end': '1600', 'day': 1},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 1},
#       {'is_overnight': False, 'start': '1100', 'end': '1600', 'day': 2},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 2},
#       {'is_overnight': False, 'start': '1100', 'end': '1600', 'day': 3},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 3},
#       {'is_overnight': False, 'start': '1100', 'end': '1600', 'day': 4},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 4},
#       {'is_overnight': False, 'start': '1100', 'end': '1600', 'day': 5},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 5},
#       {'is_overnight': False, 'start': '1100', 'end': '1600', 'day': 6},
#       {'is_overnight': False, 'start': '1700', 'end': '2200', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}},
#   {'id': 'dVunCjyOYI0g-KzZHpaqPg',
#    'alias': 'kailua-house-大阪市',
#    'name': 'KAILUA HOUSE',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/C7ERNM8XxT_-n9JEZAV11g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kailua-house-%E5%A4%A7%E9%98%AA%E5%B8%82?adjust_creative=7de9OBWOcWTBnNvd-eNKtQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=7de9OBWOcWTBnNvd-eNKtQ',
#    'review_count': 35,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.6,
#    'coordinates': {'latitude': 34.684185, 'longitude': 135.503405},
#    'transactions': [],
#    'price': '￥',
#    'location': {'address1': '中央区安土町3-2-14',
#     'address2': '',
#     'address3': None,
#     'city': 'Osaka',
#     'zip_code': '541-0052',
#     'country': 'JP',
#     'state': '27',
#     'display_address': ['中央区安土町3-2-14', 'Osaka, 大阪府 〒541-0052', 'Japan']},
#    'phone': '+81664847002',
#    'display_phone': '+81 6-6484-7002',
#    'distance': 1589.5458819458536,
#    'business_hours': [{'open': [{'is_overnight': False,
#        'start': '0730',
#        'end': '2300',
#        'day': 0},
#       {'is_overnight': False, 'start': '0730', 'end': '2300', 'day': 1},
#       {'is_overnight': False, 'start': '0730', 'end': '2300', 'day': 2},
#       {'is_overnight': False, 'start': '0730', 'end': '2300', 'day': 3},
#       {'is_overnight': False, 'start': '0730', 'end': '2300', 'day': 4},
#       {'is_overnight': False, 'start': '0800', 'end': '1700', 'day': 5},
#       {'is_overnight': False, 'start': '0800', 'end': '1700', 'day': 6}],
#      'hours_type': 'REGULAR',
#      'is_open_now': False}],
#    'attributes': {'business_temp_closed': None,
#     'menu_url': None,
#     'open24_hours': None,
#     'waitlist_reservation': None}}],
#  'total': 8400,
#  'region': {'center': {'longitude': 135.48751831054688,
#    'latitude': 34.67822047791179}}}

# %%
## example business
# yelp_genjson['businesses'][0]

## more automatic way of summarizing but things end up in lists
## within columns for things like categories
yelp_gendf = pd.DataFrame(yelp_genjson['businesses'])
yelp_gendf.head(5)
# Out:
#                        id               alias  \
# 0  Gzv9XsUt-62RbIsc9173rw    牛かつもと村-難波店-大阪市-2
# 1  PlArwOQJ79AJEVIFPtk3KA       一蘭-道頓堀店本館-大阪市
# 2  urKTDMFD2OS28iBH6pPSUA     お好み焼き-ちとせ-大阪市-2
# 3  FIvbrH1rMC3uudv2O18L-w    じねん-鰻谷南通り店-大阪市-2
# 4  tmWKNG4osApqN2GQjaaeeg  松阪牛焼肉-m-法善寺横丁店-大阪市
#
#                                        name  \
# 0                  Gyuukatsu Motomura Namba
# 1                         ICHIRAN Dotonbori
# 2                       Okonomiyaki Chitose
# 3                Jinen Unagidani Minamitori
# 4  Matsusakagyu Yakiniku M Hozenji Yokocho
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/L0_3AT...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/z_WoCW...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/wG7f5N...      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/nE7adN...      False
# 4  https://s3-media4.fl.yelpcdn.com/bphoto/3JqV_o...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/%E7%89%9B%E3%81%8B%E3...            71
# 1  https://www.yelp.com/biz/%E4%B8%80%E8%98%AD-%E...           283
# 2  https://www.yelp.com/biz/%E3%81%8A%E5%A5%BD%E3...            78
# 3  https://www.yelp.com/biz/%E3%81%98%E3%81%AD%E3...            80
# 4  https://www.yelp.com/biz/%E6%9D%BE%E9%98%AA%E7...           133
#
#                                           categories  rating  \
# 0  [{'alias': 'tempura', 'title': 'Tempura'}, {'a...     4.8
# 1             [{'alias': 'ramen', 'title': 'Ramen'}]     4.5
# 2  [{'alias': 'okonomiyaki', 'title': 'Okonomiyak...     4.8
# 3  [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.2
# 4  [{'alias': 'yakiniku', 'title': 'Yakiniku'}, {...     4.6
#
#                                         coordinates transactions price  \
# 0  {'latitude': 34.666573, 'longitude': 135.502009}           []     ￥
# 1  {'latitude': 34.669212, 'longitude': 135.503039}           []     ￥
# 2   {'latitude': 34.64751, 'longitude': 135.504734}           []     ￥
# 3   {'latitude': 34.674264, 'longitude': 135.50455}           []    ￥￥
# 4  {'latitude': 34.668139, 'longitude': 135.502569}           []   ￥￥￥
#
#                                             location          phone  \
# 0  {'address1': '中央区難波3-3-1', 'address2': '', 'ad...   +81666433313
# 1  {'address1': '中央区宗右衛門町7-18', 'address2': '田舎そば...  +815018082557
# 2  {'address1': '西成区太子1-11-10', 'address2': '', '...   +81666316002
# 3  {'address1': '中央区東心斎橋1-8-26', 'address2': None...   +81662444111
# 4  {'address1': '中央区難波1-1-19', 'address2': '', 'a...   +81662112917
#
#       display_phone     distance  \
# 0   +81 6-6643-3313  1857.773595
# 1  +81 50-1808-2557  1740.423779
# 2   +81 6-6631-6002  3768.334844
# 3   +81 6-6244-4111  1617.980138
# 4   +81 6-6211-2917  1779.034195
#
#                                       business_hours  \
# 0  [{'open': [{'is_overnight': False, 'start': '1...
# 1  [{'open': [{'is_overnight': True, 'start': '00...
# 2  [{'open': [{'is_overnight': False, 'start': '1...
# 3  [{'open': [{'is_overnight': True, 'start': '11...
# 4  [{'open': [{'is_overnight': False, 'start': '1...
#
#                                           attributes
# 0  {'business_temp_closed': None, 'menu_url': Non...
# 1  {'business_temp_closed': None, 'menu_url': 'ht...
# 2  {'business_temp_closed': None, 'menu_url': '',...
# 3  {'business_temp_closed': None, 'menu_url': 'ht...
# 4  {'business_temp_closed': None, 'menu_url': 'ht...

# %%
biz_id = 'Gzv9XsUt-62RbIsc9173rw'

# %%
base_url_reviews = f"https://api.yelp.com/v3/"
